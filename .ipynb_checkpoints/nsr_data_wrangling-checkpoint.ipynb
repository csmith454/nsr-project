# %% [markdown]
# #### NSR Project Data Wrangling

# %%
# import necessary packages
import pandas as pd
import numpy as np
import os

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_rows',None)

# %%
# open csv files as pandas dataframes 

start_y = 2011
max_y = 2024
curr_y = start_y

path = '~/desktop/projects/nsr_project/static/NSRData_CSV/'
data = {}

while curr_y <= max_y: 
    file_name = 'nsr_' + str(curr_y) + '.csv'
    df = pd.read_csv(os.path.join(path,file_name))
    data[curr_y] = df
    curr_y +=1

# %% [markdown]
# #### Define functions for use later

# %%
# Do dataset wide cleanup first?
# def functions to do some basic cleanup
def basic_clean(df):

    # replace character that make data less legible 
    df = df.replace('\n',' ', regex=True)
    df = df.replace(['«','»'], '"',regex=True)
    df = df.replace(',','.', regex=True)
    df = df.replace('-',np.nan)

    # signal non-ASCII characters within the data (to find Russian language characters that need to be translated
    n=0
    for row_index, row in df.iterrows():
        for col_name, cell_val in row.items():
            if df[col_name].dtype == object:
                if not str(cell_val).isascii():
                    n+=1
                    print('[',col_name,row_index,']')        # give location of non-ASCII characters
    print('New line characters have been removed. Detected', n, 'cell(s) with non-ASCII characters.\nNull Count:\n',df.isnull().sum())
    
    return df

# %%
# helper function that allows for more eloquent conversion 
def date_conversion_helper(to_change_dict):
    dt_list = []
    for key, item in to_change_dict:
        for s in item:
            s = pd.to_datetime(s,format=key)         # key is pattern to parse with
            dt_list.append(s)
    return dt_list

# %%
# helper function to more accurately split cells containing more than one cell worth of information
# takes in **dictionary of key, values pairs collating a regex pattern with a series
#    will the series need to be converted to ndarray?
# returns multiple series so that:
#    df[['series1','series2','series3']] = func({df[series0]:'regex pattern codes')

def splitter(series_dict):

    # dictionary that matches codes from argument to actually regex patterns
    pattern_dict = {'p':'','d':'','t':'',
                    'c':'','cm':''
                   }
    
    for series, codes in series_dict.items():
        split_codes = codes.split()

        for code in split_codes:
           # try: 
            series = series.str.extract(code)

    return 1

# %% [markdown]
# ##### Set up column standardization

# %%
# 2011

df_2011 = data[2011]
df_2011.head()
# Out:
#    Unnamed: 0    0                  1              2                  3  \
# 0           0  NaN      Vessel’s Name           Type               Flag
# 1           1  1.0       Perseverance  Tanker vessel          Singapore
# 2           2  2.0       STI Heritage  Tanker vessel  Marshall\nIslands
# 3           3  3.0            Marilee  Tanker vessel             Norway
# 4           4  4.0  Vladimir Tikhonov  Tanker vessel            Liberia
#
#                 4                     5                      6
# 0           Cargo       Port of Loading    Port of Destination
# 1  Gas condensate        Vitino, Russia         Ningbo,\nChina
# 2  Gas condensate        Vitino, Russia  Map Ta Phut, Thailand
# 3  Gas condensate        Vitino, Russia        Huizhou,\nChina
# 4  Gas condensate  Honningsvåg,\nNorway  Map Ta Phut, Thailand

# %%
df_2011.tail()
# Out:
#     Unnamed: 0     0                1                       2       3  \
# 37          37  37.0        Ventspils           Tanker vessel  Russia
# 38          38  38.0  Mikhail Kutuzov           Bulker vessel  Russia
# 39          39  39.0      Ivan Kireev  Hydrographical\nvessel  Russia
# 40          40  40.0          Vengeri         tug/supply ship  Russia
# 41          41  41.0      Mar Adriana           Tanker vessel   Spain
#
#           4            5            6
# 37  ballast         East         West
# 38  ballast         East         West
# 39  ballast  Archangelsk    Slavyanka
# 40  ballast         West         East
# 41  ballast    Rotterdam  Vladivostok

# %%
df_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  42 non-null     int64
#  1   0           41 non-null     float64
#  2   1           42 non-null     object
#  3   2           42 non-null     object
#  4   3           42 non-null     object
#  5   4           42 non-null     object
#  6   5           42 non-null     object
#  7   6           42 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.8+ KB

# %%
# make row index 0 into column headers
df_2011.columns = df_2011.iloc[0]
df_2011 = df_2011[1:]
df_2011.reset_index(drop=True, inplace=True)
df_2011.rename(columns=str)

df_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   0                    41 non-null     int64
#  1   nan                  41 non-null     float64
#  2   Vessel’s Name        41 non-null     object
#  3   Type                 41 non-null     object
#  4   Flag                 41 non-null     object
#  5   Cargo                41 non-null     object
#  6   Port of Loading      41 non-null     object
#  7   Port of Destination  41 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.7+ KB

# %%
# change column header names
df_2011.columns = ['index','index2','vessel name','ship type','flag','cargo type','port of departure','port of arrival']
df_2011.columns
# Out:
# Index(['index', 'index2', 'vessel name', 'ship type', 'flag', 'cargo type',
#        'port of departure', 'port of arrival'],
#       dtype='object')

# %%
df_2011 = df_2011.drop(['index','index2'],axis=1)

# %%
df_2011.head()
# Out:
#          vessel name      ship type               flag      cargo type  \
# 0       Perseverance  Tanker vessel          Singapore  Gas condensate
# 1       STI Heritage  Tanker vessel  Marshall\nIslands  Gas condensate
# 2            Marilee  Tanker vessel             Norway  Gas condensate
# 3  Vladimir Tikhonov  Tanker vessel            Liberia  Gas condensate
# 4     Stena Poseidon  Tanker vessel            Finland  Gas condensate
#
#       port of departure        port of arrival
# 0        Vitino, Russia         Ningbo,\nChina
# 1        Vitino, Russia  Map Ta Phut, Thailand
# 2        Vitino, Russia        Huizhou,\nChina
# 3  Honningsvåg,\nNorway  Map Ta Phut, Thailand
# 4        Vitino, Russia  Incheon,\nSouth Korea

# %%
df_2011 = basic_clean(df_2011)
# Out:
# [ port of departure 3 ]
# [ vessel name 29 ]
# New line characters have been removed. Detected 2 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name          0
# ship type            0
# flag                 0
# cargo type           0
# port of departure    0
# port of arrival      0
# dtype: int64

# %%
df_2011.head()
# Out:
#          vessel name      ship type              flag      cargo type  \
# 0       Perseverance  Tanker vessel         Singapore  Gas condensate
# 1       STI Heritage  Tanker vessel  Marshall Islands  Gas condensate
# 2            Marilee  Tanker vessel            Norway  Gas condensate
# 3  Vladimir Tikhonov  Tanker vessel           Liberia  Gas condensate
# 4     Stena Poseidon  Tanker vessel           Finland  Gas condensate
#
#      port of departure        port of arrival
# 0       Vitino. Russia          Ningbo. China
# 1       Vitino. Russia  Map Ta Phut. Thailand
# 2       Vitino. Russia         Huizhou. China
# 3  Honningsvåg. Norway  Map Ta Phut. Thailand
# 4       Vitino. Russia   Incheon. South Korea

# %%
# 2012
df_2012 = data[2012]

df_2012.head()
# Out:
#    Unnamed: 0  0                                 1                       2  \
# 0           0  №                   Vessel and Flag               Ice Class
# 1           1  1             mt\n«Varzuga»\nRussia                    Arc5
# 2           2  2              Mt\n«Indiga»\nRussia                    Arc5
# 3           3  3  Supply vessel\n«Vengeri»\nRussia  Ice 1A\nSuper\n(Arc 5)
# 4           4  4     mt\n«Nordic\nOdyssey»\nPANAMA          Ice 1A\n(Arc4)
#
#                        3                            4                    5  \
# 0  Shipowner /\nOperator                        Cargo          Destination
# 1               JSC MSCo         12538 t\nDiesel fuel         Pevek-Anadyr
# 2               JSC MSCo         12979 t\nDiesel Fuel         Pevek-Anadyr
# 3              FEMCO LTD  repositioning,\ndspl 3733 t  K holmsk,\nSakhalin
# 4  Nordic Bulk\nCarriers      67520 t\nЖРК\n«Еврохим»                Китай
#
# ...

# %%
df_2012.tail(10)
# Out:
#     Unnamed: 0              0                               1  \
# 52          52             45  icebreaker\n«Nordica»\nFINLAND
# 53          53             46  icebreaker\n«Fennica»\nFINLAND
# 54          54  Type of Cargo             Number\nof\nVessels
# 55          55         Liquid                              26
# 56          56           Bulk                               6
# 57          57           Fish                               1
# 58          58        General                             NaN
# 59          59     In Ballast                               6
# 60          60  Repositioning                               7
# 61          61         TOTAL:                              46
#
#                               2                          3  \
# 52  Polar-10\nIcebreaker\n(DNV)      Arctia Offshore\nLtd.
# 53  Polar-10\nIcebreaker\n(DNV)      Arctia Offshore\nLtd.
# 54         Cargo\nVolume,\ntons  Full\nDisplacement,\nTons
# ...

# %%
df_2012_totals = df_2012[54:62]
df_2012_totals.head(10)
# Out:
#     Unnamed: 0              0                    1                     2  \
# 54          54  Type of Cargo  Number\nof\nVessels  Cargo\nVolume,\ntons
# 55          55         Liquid                   26               894 079
# 56          56           Bulk                    6               359 201
# 57          57           Fish                    1                 8 265
# 58          58        General                  NaN                   NaN
# 59          59     In Ballast                    6                   NaN
# 60          60  Repositioning                    7                   NaN
# 61          61         TOTAL:                   46             1 261 545
#
#                             3                              4  \
# 54  Full\nDisplacement,\nTons  Number\nof Vessels\nEastbound
# 55                        NaN                             18
# 56                        NaN                              4
# 57                        NaN                            NaN
# ...

# %%
df_2012 = df_2012[0:54]
df_2012.tail()
# Out:
#     Unnamed: 0   0                                 1  \
# 49          49  42     Mv\n«Nordic\nOdyssey»\nPANAMA
# 50          50  43       mv\n«Nordic\nOrion»\nPANAMA
# 51          51  44  LNG\n«Ob River»\nMarshall Island
# 52          52  45    icebreaker\n«Nordica»\nFINLAND
# 53          53  46    icebreaker\n«Fennica»\nFINLAND
#
#                               2                      3  \
# 49               Ice 1A\n(Arc4)  Nordic Bulk\nCarriers
# 50               Ice-1A\n(Arc4)  Nordic Bulk\nCarriers
# 51               Ice 1A\n(Arc4)    LANCE\nSHIPPING S.A
# 52  Polar-10\nIcebreaker\n(DNV)  Arctia Offshore\nLtd.
# 53  Polar-10\nIcebreaker\n(DNV)  Arctia Offshore\nLtd.
#
#                                         4                  5  \
# 49                         71 786 t\ncoal  HAMBURG,\nGermany
# 50   Ballast\nFull\nDisplacement\n87216 t           Мурманск
# 51         66 342 т.,\n134 738,5 м3,\nLNG     Tobata,\nJapan
# 52  Ballast\nFull\nDisplacement\n12 800 t            Denmark
# ...

# %%
df_2012.head()
# Out:
#    Unnamed: 0  0                                 1                       2  \
# 0           0  №                   Vessel and Flag               Ice Class
# 1           1  1             mt\n«Varzuga»\nRussia                    Arc5
# 2           2  2              Mt\n«Indiga»\nRussia                    Arc5
# 3           3  3  Supply vessel\n«Vengeri»\nRussia  Ice 1A\nSuper\n(Arc 5)
# 4           4  4     mt\n«Nordic\nOdyssey»\nPANAMA          Ice 1A\n(Arc4)
#
#                        3                            4                    5  \
# 0  Shipowner /\nOperator                        Cargo          Destination
# 1               JSC MSCo         12538 t\nDiesel fuel         Pevek-Anadyr
# 2               JSC MSCo         12979 t\nDiesel Fuel         Pevek-Anadyr
# 3              FEMCO LTD  repositioning,\ndspl 3733 t  K holmsk,\nSakhalin
# 4  Nordic Bulk\nCarriers      67520 t\nЖРК\n«Еврохим»                Китай
#
# ...

# %%
# change column header names
# need to mold data into df.columns = ['index','index2','vessel name','type','flag','cargo','port of loading','port of destination']
df_2012.columns = ['index','index2', 'vessel and flag','ice class','ship operator','cargo','port of loading','port and date','entry to nsr','exit from nsr','time elapsed on nsr','avg speed','index3']
df_2012.columns
# Out:
# Index(['index', 'index2', 'vessel and flag', 'ice class', 'ship operator',
#        'cargo', 'port of loading', 'port and date', 'entry to nsr',
#        'exit from nsr', 'time elapsed on nsr', 'avg speed', 'index3'],
#       dtype='object')

# %%
df_2012 = df_2012.drop(['index','index2','index3'],axis=1)
df_2012.columns
# Out:
# Index(['vessel and flag', 'ice class', 'ship operator', 'cargo',
#        'port of loading', 'port and date', 'entry to nsr', 'exit from nsr',
#        'time elapsed on nsr', 'avg speed'],
#       dtype='object')

# %%
df_2012 = basic_clean(df_2012)
df_2012.head()
# Out:
# [ cargo 4 ]
# [ port of loading 4 ]
# [ port of loading 5 ]
# [ avg speed 8 ]
# [ avg speed 9 ]
# [ avg speed 13 ]
# [ cargo 30 ]
# [ port of loading 38 ]
# [ vessel and flag 41 ]
# [ entry to nsr 45 ]
# [ exit from nsr 45 ]
# [ ship operator 46 ]
# [ vessel and flag 48 ]
# [ port of loading 50 ]
# [ cargo 51 ]
# New line characters have been removed. Detected 15 cell(s) with non-ASCII characters.
# Null Count:
#  vessel and flag        0
# ice class              2
# ship operator          3
# cargo                  1
# port of loading        2
# port and date          1
# entry to nsr           2
# exit from nsr          4
# time elapsed on nsr    8
# avg speed              8
# dtype: int64
#                   vessel and flag             ice class         ship operator  \
# 0                 Vessel and Flag             Ice Class  Shipowner / Operator
# 1             mt "Varzuga" Russia                  Arc5              JSC MSCo
# ...

# %%
df_2012 = df_2012[1:]
df_2012.reset_index(inplace=True)
df_2012 = df_2012.drop('index',axis=1)
df_2012.head()
# Out:
#                   vessel and flag             ice class         ship operator  \
# 0             mt "Varzuga" Russia                  Arc5              JSC MSCo
# 1              Mt "Indiga" Russia                  Arc5              JSC MSCo
# 2  Supply vessel "Vengeri" Russia  Ice 1A Super (Arc 5)             FEMCO LTD
# 3      mt "Nordic Odyssey" PANAMA         Ice 1A (Arc4)  Nordic Bulk Carriers
# 4             mt "Marilee" NORWAY         Ice 1A (Arc4)             MARINVEST
#
#                             cargo             port of loading  \
# 0             12538 t Diesel fuel                Pevek-Anadyr
# 1             12979 t Diesel Fuel                Pevek-Anadyr
# 2      repositioning. dspl 3733 t          K holmsk. Sakhalin
# 3           67520 t ЖРК "Еврохим"                       Китай
# 4  60505 t gascondensat e NOVATEK  Inchеon. Republic of Korea
#
#              port and date    entry to nsr   exit from nsr  \
# 0  Murmansk 20.06.12 22:30  23.06.12 06:00  16.07.12 10:00
# ...

# %%
# split some columns to sequester info nicer
# splitting vessel and flag --> vessel, flag
# splitting port and date --> starting port, trip start date

df_2012[['vessel', 'flag']] = df_2012['vessel and flag'].str.rsplit(n=1, expand=True)
df_2012.drop('vessel and flag',axis=1,inplace=True)

df_2012[['starting port','starting date']] = df_2012['port and date'].str.split(n=1,expand=True)
df_2012.drop('port and date',axis=1, inplace=True)

# df_2012[['cargo weight','cargo type']] = df_2012['cargo'].str.split('',n=1,regex=True)
# df_2012.drop('cargo',axis=1,inplace=True)

df_2012[['starting date','starting time']] = df_2012['starting date'].str.split(n=1,expand=True)

df_2012[['nsr entry date','nsr entry time']] = df_2012['entry to nsr'].str.split(n=1,expand=True)
df_2012.drop('entry to nsr',axis=1,inplace=True)

df_2012[['nsr exit date','nsr exit time']] = df_2012['exit from nsr'].str.split(n=1,expand=True)
df_2012.drop('exit from nsr',axis=1,inplace=True)

df_2012.head()
# Out:
#               ice class         ship operator                           cargo  \
# 0                  Arc5              JSC MSCo             12538 t Diesel fuel
# 1                  Arc5              JSC MSCo             12979 t Diesel Fuel
# 2  Ice 1A Super (Arc 5)             FEMCO LTD      repositioning. dspl 3733 t
# 3         Ice 1A (Arc4)  Nordic Bulk Carriers           67520 t ЖРК "Еврохим"
# 4         Ice 1A (Arc4)             MARINVEST  60505 t gascondensat e NOVATEK
#
#               port of loading  \
# 0                Pevek-Anadyr
# 1                Pevek-Anadyr
# 2          K holmsk. Sakhalin
# 3                       Китай
# 4  Inchеon. Republic of Korea
#
#                                  time elapsed on nsr avg speed  \
# 0  To Pevek 15.4 days From Pevek to Dezhnev 4.1 days      5.8.
# 1  To Pevek 14.3 days From Pevek to Dezhnev 4.1 days       5.9
# 2                                               14.8       7.3
# ...

# %%
# fix columns that have inconsistent formatting/ additional information

df_2012['avg speed'] = df_2012['avg speed'].str.rstrip('. уз')

# regex matches and creates a consistent format for time 
# allowing for change to column dtype
df_2012['starting time'] = df_2012['starting time'].str.extract(r'((?:[01]\d|2[0-3]):[0-5]\d)',expand=False)
df_2012['nsr entry time'] = df_2012['nsr entry time'].str.extract(r'((?:[01]\d|2[0-3]):[0-5]\d)',expand=False)
df_2012['nsr exit time'] = df_2012['nsr exit time'].str.extract(r'((?:[01]\d|2[0-3]):[0-5]\d)',expand=False)

# regex matches all digits, accounting for whitespace, in a single capture group
df_2012['cargo mass'] = df_2012['cargo'].str.extract(r'((?:\d+\s*)+)')

# %%
df_2012.head()
# Out:
#               ice class         ship operator                           cargo  \
# 0                  Arc5              JSC MSCo             12538 t Diesel fuel
# 1                  Arc5              JSC MSCo             12979 t Diesel Fuel
# 2  Ice 1A Super (Arc 5)             FEMCO LTD      repositioning. dspl 3733 t
# 3         Ice 1A (Arc4)  Nordic Bulk Carriers           67520 t ЖРК "Еврохим"
# 4         Ice 1A (Arc4)             MARINVEST  60505 t gascondensat e NOVATEK
#
#               port of loading  \
# 0                Pevek-Anadyr
# 1                Pevek-Anadyr
# 2          K holmsk. Sakhalin
# 3                       Китай
# 4  Inchеon. Republic of Korea
#
#                                  time elapsed on nsr avg speed  \
# 0  To Pevek 15.4 days From Pevek to Dezhnev 4.1 days       5.8
# 1  To Pevek 14.3 days From Pevek to Dezhnev 4.1 days       5.9
# 2                                               14.8       7.3
# ...

# %%
# outlier cells need to conform

df_2012.loc[0,'time elapsed on nsr'] = 19.5
df_2012.loc[1,'time elapsed on nsr'] = 18.4

# %%
# deal with excess table headings that carried over from PDF version

df_2012.drop(9,axis=0,inplace=True)
df_2012.drop(10,axis=0,inplace=True)

df_2012.loc[8,'cargo'] = '60310 t. gas condensate NOVATEK'
df_2012.loc[8,'vessel'] = 'Mt Palva'
df_2012.loc[8,'flag'] = 'FINLAND'
df_2012.loc[8,'starting time'] = '19:30'

# %%
df_2012.drop(20,axis=0,inplace=True)
df_2012.drop(21,axis=0,inplace=True)

df_2012.loc[19,'vessel'] = 'supply vessel Tumcha (towing pipe-layer Nebula)'
df_2012.loc[19,'flag'] = 'Russia'
df_2012.loc[19,'starting port'] = 'Petropavlovsk-Kamchatskiy'
df_2012.loc[19,'starting date'] = '22.08.12'
df_2012.loc[19,'starting time'] = '14:10'

# %%
df_2012.drop(32,axis=0,inplace=True)
df_2012.drop(33,axis=0,inplace=True)

df_2012.loc[31,'cargo'] = '66275 t. Jet Fuel'
df_2012.loc[31,'port of loading'] = 'Porvoo, Finland'
df_2012.loc[31,'flag'] = 'Finland'
df_2012.loc[31,'vessel'] = 'mt Palva'
df_2012.loc[31,'starting port'] = 'Yosu, Republic of Korea'
df_2012.loc[31,'starting date'] = '05.09.12'
df_2012.loc[31,'nsr entry time'] = '10:35'
df_2012.loc[31,'nsr exit time'] = '21:30'

# %%
# clean up both cargo and cargo mass columns

df_2012['cargo mass'] = df_2012['cargo mass'].str.replace('\n','')

# create lambda function to run r split or l split based off of first character
df_2012['cargo'] = df_2012['cargo'].apply(lambda c : c.split(maxsplit=1) if str(c)[0].isnumeric() else c.rsplit(maxsplit=1))

# %%
# drop last superfluous header

df_2012.drop(43,axis=0,inplace=True)

# %%
# fix rows that are out of standard
# clear theme stands out as limitation of pdfplumber and original PDFs: 
#     multiple types of data within a single cell creates problems

df_2012.loc[0,'avg speed'] = 5.8

df_2012.loc[3,'port of loading'] = 'China'

df_2012.loc[6,'starting port'] = 'Yosu, Republic of Korea'
df_2012.loc[6,'starting date'] = '30.06.12'
df_2012.loc[6,'starting time'] = '02:15'

df_2012.loc[7,'starting port'] = 'Shanghai, China'
df_2012.loc[7,'starting date'] = np.nan
df_2012.loc[7,'starting time'] = np.nan

df_2012.loc[11,'starting port'] = 'Port Vostchnyi'
df_2012.loc[11,'starting date'] = '28.07.12'
df_2012.loc[11,'starting time'] = np.nan

df_2012.loc[13,'starting port'] = 'Port of Nakhodka'
df_2012.loc[13,'starting date'] = '05.08.12'
df_2012.loc[13,'starting time'] = '14:30'

df_2012.loc[14,'vessel'] = 'Mt "Yaroslav Mudryi"'
df_2012.loc[14,'flag'] = np.nan

df_2012.loc[15,'starting port'] = 'Huanghua, China'
df_2012.loc[15,'starting date'] = '11.08.12'
df_2012.loc[15,'starting time'] = '11:00'

df_2012.loc[16,'starting port'] = 'Yosu, Republic of Korea'
df_2012.loc[16,'starting date'] = '11.08.12'
df_2012.loc[16,'starting time'] = '13:00'

df_2012.loc[17,'vessel'] = 'mt STI Harmony'
df_2012.loc[17,'flag'] = 'Marshall Islands'

df_2012.loc[22,'starting port'] = 'Petropavlovsk-Kamchatskiy'
df_2012.loc[22,'starting date'] = '28.08.12'
df_2012.loc[22,'starting time'] = '17:00'

df_2012.loc[29,'starting port'] = 'Huanghua, China'
df_2012.loc[29,'starting date'] = '06.09.12'
df_2012.loc[29,'starting time'] = '14:00'

df_2012.loc[31,'starting time'] = np.nan

df_2012.loc[35,'starting time'] = np.nan

df_2012.loc[36,'starting port'] = 'Baydaratskaya Bay'
df_2012.loc[36,'starting date'] = '19.09.12'
df_2012.loc[36,'starting time'] = '11:00'
df_2012.loc[36,'nsr entry date'] = np.nan
df_2012.loc[36,'nsr entry time'] = np.nan

df_2012.loc[38,'starting port'] = 'Baydaratskaya Bay'
df_2012.loc[38,'starting date'] = '01.10.12'
df_2012.loc[38,'starting time'] = '17:00'

df_2012.loc[40,'vessel'] = 'LNG Ob River'
df_2012.loc[40,'flag'] = 'Marshall Islands'
df_2012.loc[40,'starting port'] = 'Yosu, Republic of Korea'
df_2012.loc[40,'starting date'] = '30.09.12'
df_2012.loc[40,'starting time'] = '01:00'

df_2012.loc[42,'starting time'] = np.nan

df_2012.loc[46,'starting port'] = 'Qinhuangdao, China'
df_2012.loc[46,'starting date'] = np.nan
df_2012.loc[46,'starting time'] = np.nan

df_2012.loc[47,'vessel'] = 'Slavyanka Bay'
df_2012.loc[47,'flag'] = 'Russia'
df_2012.loc[47,'starting port'] = 'Petropavlovsk-Kamchatskiy'
df_2012.loc[47,'starting date'] = np.nan
df_2012.loc[47,'starting time'] = np.nan

df_2012.loc[48,'starting port'] = 'Vancouver, Canada'
df_2012.loc[48,'starting date'] = '26.10.12'
df_2012.loc[48,'starting time'] = '04:00'

df_2012.loc[49,'port of loading'] = 'Murmansk'
df_2012.loc[49,'starting port'] = 'Caofeidian, China'
df_2012.loc[49,'starting date'] = '28.10.12'
df_2012.loc[49,'starting time'] = '04:00'

df_2012.loc[50,'vessel'] = 'LNG Ob River'
df_2012.loc[50,'flag'] = 'Marshall Islands'
df_2012.loc[50,'starting port'] = 'Hammerfest, Norway'
df_2012.loc[50,'starting date'] = '07.11.12'
df_2012.loc[50,'starting time'] = '18:55'

df_2012.loc[51,'starting port'] = 'Alaska, USA'
df_2012.loc[51,'starting date'] = '12.11.12'
df_2012.loc[51,'starting time'] = '08:30'

df_2012.loc[52,'starting port'] = 'Alaska, USA'
df_2012.loc[52,'starting date'] = '12.11.12'
df_2012.loc[52,'starting time'] = '07:45'


df_2012
# Out:
#                     ice class                      ship operator  \
# 0                        Arc5                           JSC MSCo
# 1                        Arc5                           JSC MSCo
# 2        Ice 1A Super (Arc 5)                          FEMCO LTD
# 3               Ice 1A (Arc4)               Nordic Bulk Carriers
# 4               Ice 1A (Arc4)                          MARINVEST
# 5               Ice-1A (Arc4)               Nordic Bulk Carriers
# 6               Ice 1A (Arc4)                          Neste Oil
# 7                       Arc 5  Polar Research Institute of China
# 8               Ice 1A (Arc4)                        "Neste Oil"
# 11                      Arc 5                        Partner LTD
# 12              Ice-1A (Arc4)               Nordic Bulk Carriers
# 13                       Arc4                        Partner LTD
# 14              Ice 1A (Arc4)               Morskoy Standart LTD
# ...

# %%
# cargo was split up for 'cargo mass' 
# need to pull out only type of cargo 
# cells will be in list form 
#     if cargo is for ballast then first item will not begin with a number

for index, cell in df_2012['cargo'].items():
    if not cell[0][0].isnumeric():
        df_2012.loc[index, 'cargo'] = 'ballast'
    else:
        df_2012.loc[index,'cargo'] = cell[1]

# remove leftover ton units

df_2012['cargo'] = df_2012['cargo'].str.split(n=1)

df_2012['cargo'] = [ cell[-1] for index, cell in df_2012['cargo'].items()]
    
df_2012.loc[3,'cargo'] = 'iron ore concentrate'

# %%
df_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 52
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ice class            46 non-null     object
#  1   ship operator        46 non-null     object
#  2   cargo                46 non-null     object
#  3   port of loading      46 non-null     object
#  4   time elapsed on nsr  41 non-null     object
#  5   avg speed            41 non-null     object
#  6   vessel               46 non-null     object
#  7   flag                 45 non-null     object
#  8   starting port        46 non-null     object
#  9   starting date        43 non-null     object
#  10  starting time        39 non-null     object
#  11  nsr entry date       45 non-null     object
#  12  nsr entry time       43 non-null     object
#  13  nsr exit date        44 non-null     object
#  14  nsr exit time        42 non-null     object
# ...

# %%
# convert columns to more specific data types

df_2012['time elapsed on nsr'] = pd.to_numeric(df_2012['time elapsed on nsr'])
df_2012['avg speed'] = pd.to_numeric(df_2012['avg speed'])

df_2012['cargo mass'] = df_2012['cargo mass'].str.replace(" ","",regex=True)
df_2012['cargo mass'] = df_2012['cargo mass'].str.replace("\n","",regex=True)
df_2012['cargo mass'] = pd.to_numeric(df_2012['cargo mass'])
df_2012.drop('cargo mass',axis=1,inplace=True)

df_2012['starting date'] = pd.to_datetime(df_2012['starting date'],format='%d.%m.%y')
df_2012['nsr entry date'] = pd.to_datetime(df_2012['nsr entry date'],format='%d.%m.%y')
df_2012['nsr exit date'] = pd.to_datetime(df_2012['nsr exit date'],format='%d.%m.%y')

df_2012['starting time'] = pd.to_datetime(df_2012['starting time'],format='%H:%M')
df_2012['nsr entry time'] = pd.to_datetime(df_2012['nsr entry time'],format='%H:%M')
df_2012['nsr exit time'] = pd.to_datetime(df_2012['nsr exit time'],format='%H:%M')

df_2012['starting time'] = df_2012['starting time'].dt.strftime('%H:%M')
df_2012['nsr entry time'] = df_2012['nsr entry time'].dt.strftime('%H:%M')
df_2012['nsr exit time'] = df_2012['nsr exit time'].dt.strftime('%H:%M')

df_2012[['ice class','ship operator','cargo','port of loading','vessel','flag','starting port']] = df_2012[['ice class','ship operator','cargo','port of loading','vessel','flag','starting port']].astype('str')

df_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 52
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ice class            46 non-null     object
#  1   ship operator        46 non-null     object
#  2   cargo                46 non-null     object
#  3   port of loading      46 non-null     object
#  4   time elapsed on nsr  41 non-null     float64
#  5   avg speed            41 non-null     float64
#  6   vessel               46 non-null     object
#  7   flag                 46 non-null     object
#  8   starting port        46 non-null     object
#  9   starting date        43 non-null     datetime64[ns]
#  10  starting time        39 non-null     object
#  11  nsr entry date       45 non-null     datetime64[ns]
#  12  nsr entry time       43 non-null     object
#  13  nsr exit date        44 non-null     datetime64[ns]
#  14  nsr exit time        42 non-null     object
# ...

# %%
df_2012.columns = [
    'ice class','ship operator','cargo type','port of arrival','time elapsed on nsr','avg speed',
    'vessel name','flag','port of departure','date of departure','time of departure','nsr entry date',
    'nsr entry time','nsr exit date','nsr exit time'
]

# %%
df_2012.head()
# Out:
#               ice class         ship operator              cargo type  \
# 0                  Arc5              JSC MSCo             Diesel fuel
# 1                  Arc5              JSC MSCo             Diesel Fuel
# 2  Ice 1A Super (Arc 5)             FEMCO LTD                 ballast
# 3         Ice 1A (Arc4)  Nordic Bulk Carriers    iron ore concentrate
# 4         Ice 1A (Arc4)             MARINVEST  gascondensat e NOVATEK
#
#               port of arrival  time elapsed on nsr  avg speed  \
# 0                Pevek-Anadyr                 19.5        5.8
# 1                Pevek-Anadyr                 18.4        5.9
# 2          K holmsk. Sakhalin                 14.8        7.3
# 3                       China                 11.2        9.7
# 4  Inchеon. Republic of Korea                 11.3        9.6
#
#                vessel name    flag port of departure date of departure  \
# 0             mt "Varzuga"  Russia          Murmansk        2012-06-20
# ...

# %%
# 2013

df_2013 = data[2013]
df_2013.head()
# Out:
#    Unnamed: 0    0                                    1               2  \
# 0           0  No.                      Vessel and Flag       Ice class
# 1           1    1           mt\n«Varzuga»\nflag RUSSIA            Arc5
# 2           2    2            mt\n«Indiga»\nflag RUSSIA            Arc5
# 3           3    3      mv\n«Nordic Orion»\nflag PANAMA  Ice-1A\n(Arc4)
# 4           4    4  mv\n«Boris Vilkitskiy»\nflag RUSSIA            Arc4
#
#              3                                  4  \
# 0  GRT,\ntones             Vessel\nowner/operator
# 1       11 290                 MSCO /\nChukotsnab
# 2       11 290                 MSCO /\nChukotsnab
# 3       40 142              Nordic Bulk\nCarriers
# 4        5 025  Khatanga Sea\nMerchant Port\nCJSC
#
#                                   5                     6  \
# 0                             Cargo  Port of\ndestination
# 1         13 658 tones\ndiesel fuel     Певек -\nNakhodka
# ...

# %%
df_2013.tail(10)
# Out:
#     Unnamed: 0               0                                          1  \
# 75          75              67  mv «HHL Lagos»\nflag Antigua and\nBarbuda
# 76          76              68                     mv «Yuri\nArshenevsky»
# 77          77  Type of\ncargo                        Amount\nof\nvessels
# 78          78          Liquid                                         31
# 79          79            Bulk                                          4
# 80          80             LNG                                          1
# 81          81   General cargo                                         13
# 82          82      Ballasting                                         15
# 83          83      Reposition                                          7
# 84          84          TOTAL:                                         71
#
#                         2                         3                4  \
# 75         Ice 1A\n(Arc4)                    17 644  Hansa Heavylift
# ...

# %%
df_2013_totals = df_2013[77:85]
df_2013_totals.head(10)
# Out:
#     Unnamed: 0               0                    1                      2  \
# 77          77  Type of\ncargo  Amount\nof\nvessels  Cargo\nvolume,\ntones
# 78          78          Liquid                   31                911 867
# 79          79            Bulk                    4                276 939
# 80          80             LNG                    1                 66 868
# 81          81   General cargo                   13                100 223
# 82          82      Ballasting                   15                    NaN
# 83          83      Reposition                    7                    NaN
# 84          84          TOTAL:                   71              1 355 897
#
#                            3            4                                5  \
# 77  Full displ.\n(FD), tones  GRT,\ntones  Laden\nvessels\neastbound\n(EB)
# 78                       NaN      666 956                               23
# ...

# %%
df_2013 = df_2013[:77]
df_2013.tail()
# Out:
#     Unnamed: 0   0                                          1  \
# 72          72  64          mv «HHL Hong\nKong»\nflag LIBERIA
# 73          73  65        icebreaker\n«Fennica»\nflag FINLAND
# 74          74  66                  mt\n«Indiga»\nflag RUSSIA
# 75          75  67  mv «HHL Lagos»\nflag Antigua and\nBarbuda
# 76          76  68                     mv «Yuri\nArshenevsky»
#
#                               2       3                      4  \
# 72               Ice 1A\n(Arc4)  17 634        Hansa Heavylift
# 73  Polar-10\nIcebreaker\n(DNV)   9 392  Arctia Offshore\nLtd.
# 74                         Arc5  11 290     MSCO /\nChukotsnab
# 75               Ice 1A\n(Arc4)  17 644        Hansa Heavylift
# 76                         Arc7  18 574                   MSCO
#
#                                 5                  6  \
# 72     1 742 tones\ngeneral cargo  Rajin\n(N. Kores)
# 73  reposition,\nFD\n12 800 tones  Kirkenes,\nNorway
# ...

# %%
df_2013.columns = ['index','index2','vessel and flag','ice class','grt (tons)','vessel operator','cargo','port of destination','port and date of departure','entry to nsr','exit from nsr','time elapsed on nsr','avg speed (knots)','index3','index4','index5']
df_2013.head()
# Out:
#    index index2                      vessel and flag       ice class  \
# 0      0    No.                      Vessel and Flag       Ice class
# 1      1      1           mt\n«Varzuga»\nflag RUSSIA            Arc5
# 2      2      2            mt\n«Indiga»\nflag RUSSIA            Arc5
# 3      3      3      mv\n«Nordic Orion»\nflag PANAMA  Ice-1A\n(Arc4)
# 4      4      4  mv\n«Boris Vilkitskiy»\nflag RUSSIA            Arc4
#
#     grt (tons)                    vessel operator  \
# 0  GRT,\ntones             Vessel\nowner/operator
# 1       11 290                 MSCO /\nChukotsnab
# 2       11 290                 MSCO /\nChukotsnab
# 3       40 142              Nordic Bulk\nCarriers
# 4        5 025  Khatanga Sea\nMerchant Port\nCJSC
#
#                               cargo   port of destination  \
# 0                             Cargo  Port of\ndestination
# 1         13 658 tones\ndiesel fuel     Певек -\nNakhodka
# 2         13 645 tones\ndiesel fuel                 Pevek
# ...

# %%
df_2013 = df_2013.drop(['index','index2','index3','index4','index5'],axis=1)
df_2013 = df_2013.drop([0],axis=0)
df_2013.head()
# Out:
#                        vessel and flag       ice class grt (tons)  \
# 1           mt\n«Varzuga»\nflag RUSSIA            Arc5     11 290
# 2            mt\n«Indiga»\nflag RUSSIA            Arc5     11 290
# 3      mv\n«Nordic Orion»\nflag PANAMA  Ice-1A\n(Arc4)     40 142
# 4  mv\n«Boris Vilkitskiy»\nflag RUSSIA            Arc4      5 025
# 5            mt\n«Indiga»\nflag RUSSIA            Arc5     11 290
#
#                      vessel operator                             cargo  \
# 1                 MSCO /\nChukotsnab         13 658 tones\ndiesel fuel
# 2                 MSCO /\nChukotsnab         13 645 tones\ndiesel fuel
# 3              Nordic Bulk\nCarriers  66 000 tones\niron ore\nEurochem
# 4  Khatanga Sea\nMerchant Port\nCJSC          5 996 tones\ndiesel fuel
# 5                  MSCO/\nChukotsnab     ballasting,\nFD 22 654\ntones
#
#   port of destination port and date of departure  \
# 1   Певек -\nNakhodka  Murmansk\n25.06.13\n00:00
# ...

# %%
df_2013 = basic_clean(df_2013)
# Out:
# [ port of destination 1 ]
# [ vessel and flag 10 ]
# [ cargo 34 ]
# [ port and date of departure 75 ]
# New line characters have been removed. Detected 4 cell(s) with non-ASCII characters.
# Null Count:
#  vessel and flag               1
# ice class                     2
# grt (tons)                    3
# vessel operator               2
# cargo                         1
# port of destination           1
# port and date of departure    1
# entry to nsr                  1
# exit from nsr                 1
# time elapsed on nsr           3
# avg speed (knots)             3
# dtype: int64

# %%
df_2013.head()
# Out:
#                      vessel and flag      ice class grt (tons)  \
# 1           mt "Varzuga" flag RUSSIA           Arc5     11 290
# 2            mt "Indiga" flag RUSSIA           Arc5     11 290
# 3      mv "Nordic Orion" flag PANAMA  Ice-1A (Arc4)     40 142
# 4  mv "Boris Vilkitskiy" flag RUSSIA           Arc4      5 025
# 5            mt "Indiga" flag RUSSIA           Arc5     11 290
#
#                    vessel operator                           cargo  \
# 1                MSCO / Chukotsnab        13 658 tones diesel fuel
# 2                MSCO / Chukotsnab        13 645 tones diesel fuel
# 3             Nordic Bulk Carriers  66 000 tones iron ore Eurochem
# 4  Khatanga Sea Merchant Port CJSC         5 996 tones diesel fuel
# 5                 MSCO/ Chukotsnab     ballasting. FD 22 654 tones
#
#   port of destination port and date of departure  \
# 1    Певек - Nakhodka    Murmansk 25.06.13 00:00
# 2               Pevek    Murmansk 25.06.13 19:00
# ...

# %%
# split columns into standardized column format

df_2013[['vessel','flag']] = df_2013['vessel and flag'].str.split('flag',n=1,expand=True)
df_2013.drop('vessel and flag', axis=1,inplace=True)

df_2013[['starting port','starting date','starting time']] = df_2013['port and date of departure'].str.split(n=2,expand=True)
df_2013.drop('port and date of departure',axis=1,inplace=True)

df_2013[['nsr entry date','nsr entry time','nsr entry location']] = df_2013['entry to nsr'].str.split(n=2,expand=True)
df_2013.drop('entry to nsr',axis=1,inplace=True)

df_2013[['nsr exit date','nsr exit time','nsr exit location']] = df_2013['exit from nsr'].str.split(n=2,expand=True)
df_2013.drop('exit from nsr',axis=1,inplace=True)

df_2013.head()
# Out:
#        ice class grt (tons)                  vessel operator  \
# 1           Arc5     11 290                MSCO / Chukotsnab
# 2           Arc5     11 290                MSCO / Chukotsnab
# 3  Ice-1A (Arc4)     40 142             Nordic Bulk Carriers
# 4           Arc4      5 025  Khatanga Sea Merchant Port CJSC
# 5           Arc5     11 290                 MSCO/ Chukotsnab
#
#                             cargo port of destination time elapsed on nsr  \
# 1        13 658 tones diesel fuel    Певек - Nakhodka                15.3
# 2        13 645 tones diesel fuel               Pevek                11.7
# 3  66 000 tones iron ore Eurochem      Lanshan. China                19.9
# 4         5 996 tones diesel fuel        Khatanga Bay                25.2
# 5     ballasting. FD 22 654 tones              Ob Bay                11.3
#
#   avg speed (knots)                  vessel     flag starting port  \
# 1               7.0           mt "Varzuga"    RUSSIA      Murmansk
# ...

# %%
# split cargo into cargo and cargo mass

# create lambda function to run r split or l split based off of first character
df_2013['cargo'] = df_2013['cargo'].apply(lambda c : str(c).rsplit('tones',maxsplit=1) if str(c)[0].isnumeric() else str(c).split(maxsplit=1))

for index, cell in df_2013['cargo'].items():
    if not cell[0][0].isnumeric():
        df_2013.loc[index, 'cargo'] = 'ballast'
        df_2013.loc[index,'cargo mass'] = cell[-1]
    else:
        df_2013.loc[index,'cargo'] = cell[-1]
        df_2013.loc[index,'cargo mass'] = cell[0]

# %%
df_2013.head()
# Out:
#        ice class grt (tons)                  vessel operator  \
# 1           Arc5     11 290                MSCO / Chukotsnab
# 2           Arc5     11 290                MSCO / Chukotsnab
# 3  Ice-1A (Arc4)     40 142             Nordic Bulk Carriers
# 4           Arc4      5 025  Khatanga Sea Merchant Port CJSC
# 5           Arc5     11 290                 MSCO/ Chukotsnab
#
#                 cargo port of destination time elapsed on nsr  \
# 1         diesel fuel    Певек - Nakhodka                15.3
# 2         diesel fuel               Pevek                11.7
# 3   iron ore Eurochem      Lanshan. China                19.9
# 4         diesel fuel        Khatanga Bay                25.2
# 5             ballast              Ob Bay                11.3
#
#   avg speed (knots)                  vessel     flag starting port  \
# 1               7.0           mt "Varzuga"    RUSSIA      Murmansk
# 2               9.2            mt "Indiga"    RUSSIA      Murmansk
# ...

# %%
df_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 1 to 76
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ice class            74 non-null     object
#  1   grt (tons)           73 non-null     object
#  2   vessel operator      74 non-null     object
#  3   cargo                76 non-null     object
#  4   port of destination  75 non-null     object
#  5   time elapsed on nsr  73 non-null     object
#  6   avg speed (knots)    73 non-null     object
#  7   vessel               75 non-null     object
#  8   flag                 66 non-null     object
#  9   starting port        75 non-null     object
#  10  starting date        66 non-null     object
#  11  starting time        53 non-null     object
#  12  nsr entry date       75 non-null     object
#  13  nsr entry time       73 non-null     object
#  14  nsr entry location   72 non-null     object
# ...

# %%
# remove superfluous header rows

df_2013.drop(11,axis=0,inplace=True)
df_2013.drop(23,axis=0,inplace=True)
df_2013.drop(36,axis=0,inplace=True)
df_2013.drop(37,axis=0,inplace=True)
df_2013.drop(49,axis=0,inplace=True)
df_2013.drop(63,axis=0,inplace=True)

# %%
# correct cells that do not follow format

df_2013.loc[1,'port of destination'] = 'Pevek-Nakhodka'

df_2013.loc[7,'starting port'] = 'Beilun, China'
df_2013.loc[7,'starting date'] = '10.07.13'
df_2013.loc[7,'starting time'] = '02:00'

df_2013.loc[9,'starting port'] = 'Petropavlovsk-Kamchatsky'
df_2013.loc[9,'starting date'] = np.nan
df_2013.loc[9,'starting time'] = np.nan

df_2013.loc[10,'vessel'] = 'mv "Georgiy Ushakov"'
df_2013.loc[10,'flag'] = 'Russia'

df_2013.loc[12,'starting port'] = 'Mongstad, Norway'
df_2013.loc[12, 'starting date'] = '17.07.13'
df_2013.loc[12,'starting time'] = np.nan

df_2013.loc[15,'starting port'] = 'Ob Bay'
df_2013.loc[15,'starting time'] = '22:00'
df_2013.loc[15,'starting date'] = '26.07.13'

df_2013.loc[22,'starting port'] = 'Tan Cang Cai Mep, Vietnam'
df_2013.loc[22,'starting date'] = np.nan
df_2013.loc[22,'starting time'] = np.nan

df_2013.loc[26,'starting port'] = 'Ob Bay'
df_2013.loc[26,'starting time'] = '12:00'
df_2013.loc[26,'starting date'] = '13.08.13'

df_2013.loc[29,'starting port'] = 'Ob Bay'
df_2013.loc[29,'starting time'] = '20:00'
df_2013.loc[29,'starting date'] = '25.08.13'

df_2013.loc[35,'starting port'] = 'Petropavlovsk-Kamchatsky'
df_2013.loc[35,'starting time'] = np.nan
df_2013.loc[35,'starting date'] = '03.09.13'

df_2013.loc[41,'starting port'] = 'Alesund, Norway'
df_2013.loc[41,'starting time'] = np.nan
df_2013.loc[41,'starting date'] = np.nan

df_2013.loc[43,'starting port'] = 'c. Shmidt'
df_2013.loc[43,'starting time'] = '20:00'
df_2013.loc[43,'starting date'] = '16.09.13'

df_2013.loc[45,'starting port'] = 'Ob Bay'
df_2013.loc[45,'starting time'] = '12:00'
df_2013.loc[45,'starting date'] = '18.08.13'

df_2013.loc[46,'starting port'] = 'Hammerfest, Norway'
df_2013.loc[46,'starting time'] = np.nan
df_2013.loc[46,'starting date'] = '13.09.13'

df_2013.loc[48,'starting port'] = 'Petropavlovsk-Kamchatsky'
df_2013.loc[48,'starting time'] = '12:50'
df_2013.loc[48,'starting date'] = '10.09.13'
df_2013.loc[48,'vessel'] = 'mv "Inzhener Trubin"'
df_2013.loc[48,'port of destination'] = 'Arkhangelsk'
df_2013.loc[48,'cargo'] = 'general cargo'
df_2013.loc[48,'flag'] = 'Russia'
df_2013.loc[48,'nsr entry date'] = '23.09.13'
df_2013.loc[48,'nsr exit date'] = '28.10.13'
df_2013.loc[48,'nsr entry time'] = '18:00'
df_2013.loc[48,'nsr exit time'] = '12:45'
df_2013.loc[48,'nsr entry location'] = 'c. Dezhnev'
df_2013.loc[48,'nsr exit location'] = 'Kara Gate'
df_2013.drop(50,axis=0,inplace=True)

# %%
df_2013
# Out:
#                     ice class grt (tons)                  vessel operator  \
# 1                        Arc5     11 290                MSCO / Chukotsnab
# 2                        Arc5     11 290                MSCO / Chukotsnab
# 3               Ice-1A (Arc4)     40 142             Nordic Bulk Carriers
# 4                        Arc4      5 025  Khatanga Sea Merchant Port CJSC
# 5                        Arc5     11 290                 MSCO/ Chukotsnab
# 6                        Arc4      4 110                          Sky LLC
# 7               Ice 1A (Arc4)     40 142             Nordic Bulk Carriers
# 8                        Arc5      6 418        Northern Shipping Company
# 9                        Arc5     13 204                Vostokbunker CJSC
# 10                       Arc4      6 204  Khatanga Sea Merchant Port CJSC
# 12              Ice 1A (Arc4)     66 919               TSAKOS COLUMBIA SM
# 13                      Arc 5      4 724                          Sky LLC
# ...

# %%
# continue on manual fixes

# df_2013.loc[51,'starting port'] = 'Ulsan, South Korea'
# df_2013.loc[51,'starting date'] = '14.09.13'
# df_2013.loc[51,'starting time'] = np.nan

# df_2013.loc[52,'starting port'] = 'Ob Bay'
# df_2013.loc[52,'starting date'] = '26.09.13'
# df_2013.loc[52,'starting time'] = '18:00'

# df_2013.loc[53,'starting port'] = 'Mongstad, Norway'
# df_2013.loc[53,'starting date'] = '21.09.13'
# df_2013.loc[53,'starting time'] = np.nan

# df_2013.loc[55,'starting port'] = 'Kirkenes, Norway'
# df_2013.loc[55,'starting date'] = np.nan
# df_2013.loc[55,'starting time'] = np.nan

# df_2013.loc[57,'starting port'] = 'Onsan, South Korea'
# df_2013.loc[57,'starting date'] = np.nan
# df_2013.loc[57,'starting time'] = np.nan

# df_2013.loc[64,'vessel'] = 'mt "Viktor Bakaev"'
# df_2013.loc[64,'port of destination'] = 'Rotterdam, Netherlands'
# df_2013.loc[64,'cargo'] = 'ballast'
# df_2013.loc[64,'flag'] = 'Liberia'
# df_2013.loc[64,'nsr entry date'] = '23.09.13'
# df_2013.loc[64,'nsr exit date'] = '28.10.13'
# df_2013.loc[64,'nsr entry time'] = '18:00'
# df_2013.loc[64,'nsr exit time'] = '12:45'
# df_2013.loc[64,'nsr entry location'] = 'c. Dezhnev'
# df_2013.loc[64,'nsr exit location'] = 'Kara Gate'
# df_2013.loc[64,'starting port'] = 'Yosu, South Korea'
# df_2013.loc[64,'starting date'] = '2.10.13'
# df_2013.loc[64,'starting time'] = '09:00'
# drop 62?

# %%
# change column types for non-string columns

# df_2013['grt'] = df_2013['grt (tons)'].str.replace(' ','',regex=True)
# df_2013['grt'] = pd.to_numeric(df_2013['grt'])
# df_2013.drop('grt (tons)',axis=1,inplace=True)

# df_2013['time elapsed on nsr'] = pd.to_numeric(df_2013['time elapsed on nsr'])
# df_2013['avg speed'] = pd.to_numeric(df_2013['avg speed (knots)'])
# df_2013.drop('avg speed (knots)',axis=1,inplace=True)

# # pull out digits from string with regex
# ser_exp = [df_2013['starting date'],df_2013['nsr entry date'],df_2013['nsr exit date']]

# for c in ser_exp:
#     try:
#         c = pd.to_datetime

# df_2013['cargo mass'] = df_2013['cargo mass'].str.extract(r'((?:\d+\s*)+)')
# df_2013['cargo mass'] = df_2013['cargo mass'].str.replace(' ','')
# df_2013['cargo mass'] = pd.to_numeric(df_2013['cargo mass'])

# df_2013['starting date'] = pd.to_datetime(df_2013['starting date'],format='%d.%m.%y')
# df_2013['nsr entry date'] = pd.to_datetime(df_2013['nsr entry date'],format='%d.%m.%y')
# df_2013['nsr exit date'] = pd.to_datetime(df_2013['nsr exit date'],format='%d.%m.%y')

# df_2013['starting time'] = pd.to_datetime(df_2013['starting time'],format='%H:%M')
# df_2013['nsr entry time'] = pd.to_datetime(df_2013['nsr entry time'],format='%H:%M')
# df_2013['nsr exit time'] = pd.to_datetime(df_2013['nsr exit time'],format='%H:%M')

# df_2013['starting time'] = df_2013['starting time'].dt.strftime('%H:%M')
# df_2013['nsr entry time'] = df_2013['nsr entry time'].dt.strftime('%H:%M')
# df_2013['nsr exit time'] = df_2013['nsr exit time'].dt.strftime('%H:%M')

# df_2013.head()
df_2013.columns = ['ice class','grt','ship operator','cargo type','port of arrival',
                   'time elapsed on nsr','avg speed (knots)','vessel name','flag','port of departure',
                   'date of departure','time of departure','nsr entry date','nsr entry time',
                   'nsr entry location','nsr exit date','nsr exit time','nsr exit location',
                   'approx cargo weight (tn)'
            ]

temp_df_2013 = df_2013.copy()

# %%
df_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69 entries, 1 to 76
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ice class                 69 non-null     object
#  1   grt                       68 non-null     object
#  2   ship operator             68 non-null     object
#  3   cargo type                69 non-null     object
#  4   port of arrival           69 non-null     object
#  5   time elapsed on nsr       68 non-null     object
#  6   avg speed (knots)         68 non-null     object
#  7   vessel name               69 non-null     object
#  8   flag                      67 non-null     object
#  9   port of departure         68 non-null     object
#  10  date of departure         58 non-null     object
#  11  time of departure         44 non-null     object
#  12  nsr entry date            69 non-null     object
#  13  nsr entry time            68 non-null     object
# ...

# %%
# 2014

df_2014 = data[2014]
df_2014.head()
# Out:
#    Unnamed: 0                                                  0  \
# 0           0                                     Name of vessel
# 1           1  List of the vessels crossed both Western and E...
# 2           2                                                  1
# 3           3                                                  2
# 4           4                                                  3
#
#                     1       2                          3       4  \
# 0                 NaN    Flag                       Type     GRT
# 1                 NaN     NaN                        NaN     NaN
# 2  Kapitan Khlebnikov  Russia            Passengers Ship  12 288
# 3          Tor Viking  Sweden  Tug / Supply / Icebreaker   3 382
# 4     Anichkov Bridge  Russia        Oil/Chemical Tanker  27 829
#
#                                                 5            6  \
# 0  Date and place of entering the\nNSR water area          NaN
# ...

# %%
df_2014.tail()
# Out:
#     Unnamed: 0   0            1       2                 3       4         5  \
# 51          51  18      Varzuga  Russia  Crude Oil Tanker  11 290  17.10.14
# 52          52  19       Indiga  Russia  Crude Oil Tanker  11 290  20.10.14
# 53          53  20      Varzuga  Russia  Crude Oil Tanker  11 290  31.10.14
# 54          54  21       Indiga  Russia  Crude Oil Tanker  11 290  04.11.14
# 55          55  22  Ivan Ryabov  Russia     General Cargo   5 370  06.11.14
#
#                   6            7         8   9
# 51  Karskiye Vorota   port Pevek  28.10.14  11
# 52       port Pevek  c. Zhelania  17.11.14  28
# 53       port Pevek  c. Zhelania  17.11.14  17
# 54       port Pevek  c. Zhelania  17.11.14  13
# 55       port Pevek  c. Zhelania  16.11.14  10

# %%
# rename columns to get closer to standardization

df_2014.columns = ['index','index2','vessel name','flag','cargo type','grt','nsr entry date','nsr entry location','nsr exit location','nsr exit date','time elapsed on nsr']
df_2014.head()
# Out:
#    index                                             index2  \
# 0      0                                     Name of vessel
# 1      1  List of the vessels crossed both Western and E...
# 2      2                                                  1
# 3      3                                                  2
# 4      4                                                  3
#
#           vessel name    flag                 cargo type     grt  \
# 0                 NaN    Flag                       Type     GRT
# 1                 NaN     NaN                        NaN     NaN
# 2  Kapitan Khlebnikov  Russia            Passengers Ship  12 288
# 3          Tor Viking  Sweden  Tug / Supply / Icebreaker   3 382
# 4     Anichkov Bridge  Russia        Oil/Chemical Tanker  27 829
#
#                                    nsr entry date nsr entry location  \
# 0  Date and place of entering the\nNSR water area                NaN
# 1                                             NaN                NaN
# ...

# %%
# drop irrelevant columns and rows
df_2014.drop('index',axis=1,inplace=True)
df_2014.drop('index2',axis=1,inplace=True)
df_2014.drop(0,axis=0,inplace=True)
df_2014.drop(1,axis=0,inplace=True)

df_2014.reset_index(drop=True,inplace=True)

df_2014.head()
# Out:
#           vessel name    flag                 cargo type     grt  \
# 0  Kapitan Khlebnikov  Russia            Passengers Ship  12 288
# 1          Tor Viking  Sweden  Tug / Supply / Icebreaker   3 382
# 2     Anichkov Bridge  Russia        Oil/Chemical Tanker  27 829
# 3                Oden  Sweden        Icebreaker/Research   9 605
# 4     Yaroslav Mydryy  Russia        Oil/Chemical Tanker   6 262
#
#   nsr entry date    nsr entry location    nsr exit location nsr exit date  \
# 0       28.06.14            c. Dezhnev          c. Zhelania      28.07.14
# 1       03.07.14           c. Zhelania           c. Dezhnev      16.07.14
# 2       05.07.14            c. Dezhnev          c. Zhelania      17.08.14
# 3       09.07.14  North of c. Zhelania  North of c. Dezhnev      17.08.14
# 4       09.07.14            c. Dezhnev          c. Zhelania      28.07.14
#
#   time elapsed on nsr
# 0                  30
# 1                  13
# 2                  43
# 3                  39
# ...

# %%
df_2014 = basic_clean(df_2014)
# Out:
# New line characters have been removed. Detected 0 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name            1
# flag                   1
# cargo type             1
# grt                    1
# nsr entry date         1
# nsr entry location     1
# nsr exit location      1
# nsr exit date          1
# time elapsed on nsr    1
# dtype: int64

# %%
# 2015

df_2015 = data[2015]
df_2015.head()
# Out:
#    Unnamed: 0  0                                          1  \
# 0           0  №                                Vessel name
# 1           1  1  Yasnyi (with\nfloating crane СПК-\n42150)
# 2           2  2                                 Yong Sheng
# 3           3  3                                 Winter Bay
# 4           4  4                                   Garmonia
#
#                     2                    3                    4  \
# 0                Flag            Shipowner            Ice class
# 1              Russia            FBI "MRS"  Arc 5\n(crane Ice2)
# 2               China       Cosco Shipping                Arc 4
# 3  St. Kitts &\nNevis         Dalriada Ltd                Ice 1
# 4              Russia  Yuzmorrybflot\nLtd.                Arc 4
#
#                          5                                                  6  \
# 0                     Type                                              Cargo
# ...

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20 non-null     int64
#  1   0           20 non-null     object
#  2   1           19 non-null     object
#  3   2           19 non-null     object
#  4   3           19 non-null     object
#  5   4           19 non-null     object
#  6   5           19 non-null     object
#  7   6           13 non-null     object
#  8   7           20 non-null     object
#  9   8           20 non-null     object
#  10  9           19 non-null     object
#  11  10          19 non-null     object
#  12  11          19 non-null     object
#  13  12          13 non-null     object
#  14  13          7 non-null      object
#  15  14          19 non-null     object
#  16  15          20 non-null     object
# dtypes: int64(1), object(16)
# memory usage: 2.8+ KB

# %%
df_2015.tail()
# Out:
#     Unnamed: 0      0             1       2  \
# 15          15     15  Volk Arktiki  Russia
# 16          16     16      Palladiy  Russia
# 17          17     17      Kigoriak  Russia
# 18          18     18    Tor Viking  Sweden
# 19          19  Total           NaN     NaN
#
#                                        3      4          5        6  \
# 15  LLC\nRiboloveckaya\nArtel Vilychinsk  Ice 3   Fishinng  Ballast
# 16                            Valkur Ltd  Arc 5     Tanker  Ballast
# 17                            Femco Mng.   Ib 6  Iceb. Tug      NaN
# 18              Viking Supply\nShips A/S  Arc 7  Iceb. Tug      NaN
# 19                                   NaN    NaN        NaN      NaN
#
#              7        8                            9                     10  \
# 15           0      4,0  Petropavlovsk-\nKamchatskiy               Murmansk
# 16           0      6,4  Petropavlovsk-\nKamchatskiy               Murmansk
# ...

# %%
# rename columns to closer adhere to standardization

df_2015.columns = ['index','index2','vessel name','flag','ship operator',
                   'ice class','ship type','cargo type','approx cargo weight (tn)',
                   'max draught','port of departure','port of arrival',
                   'icebreaker assistance','Kara Gate date and time','Cape Zhelaniya date and time',
                   'Cape Dezhnev date and time','time elapsed on nsr'
                  ]
df_2015.head()
# Out:
#    index index2                                vessel name  \
# 0      0      №                                Vessel name
# 1      1      1  Yasnyi (with\nfloating crane СПК-\n42150)
# 2      2      2                                 Yong Sheng
# 3      3      3                                 Winter Bay
# 4      4      4                                   Garmonia
#
#                  flag        ship operator            ice class  \
# 0                Flag            Shipowner            Ice class
# 1              Russia            FBI "MRS"  Arc 5\n(crane Ice2)
# 2               China       Cosco Shipping                Arc 4
# 3  St. Kitts &\nNevis         Dalriada Ltd                Ice 1
# 4              Russia  Yuzmorrybflot\nLtd.                Arc 4
#
#                  ship type                                         cargo type  \
# 0                     Type                                              Cargo
# ...

# %%
# drop irrelevant columns and rows

df_2015.drop(19,axis=0,inplace=True)
df_2015.drop(0,axis=0,inplace=True)
df_2015.drop('index',axis=1,inplace=True)
df_2015.drop('index2',axis=1,inplace=True)

df_2015.head()
# Out:
#                                  vessel name                flag  \
# 1  Yasnyi (with\nfloating crane СПК-\n42150)              Russia
# 2                                 Yong Sheng               China
# 3                                 Winter Bay  St. Kitts &\nNevis
# 4                                   Garmonia              Russia
# 5                                  Happy Sky         Netherlands
#
#             ship operator            ice class                ship type  \
# 1               FBI "MRS"  Arc 5\n(crane Ice2)                   Rescue
# 2          Cosco Shipping                Arc 4  General\ncargo\ncarrier
# 3            Dalriada Ltd                Ice 1                   Reefer
# 4     Yuzmorrybflot\nLtd.                Arc 4                   Reefer
# 5  BigLift Shipping\nB.V.                Arc 4  General\ncargo\ncarrier
#
#                                           cargo type approx cargo weight (tn)  \
# ...

# %%
df_2015 = basic_clean(df_2015)
# Out:
# [ vessel name 1 ]
# [ vessel name 8 ]
# New line characters have been removed. Detected 2 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name                      0
# flag                             0
# ship operator                    0
# ice class                        0
# ship type                        0
# cargo type                       6
# approx cargo weight (tn)         0
# max draught                      0
# port of departure                0
# port of arrival                  0
# icebreaker assistance            0
# Kara Gate date and time          6
# Cape Zhelaniya date and time    12
# Cape Dezhnev date and time       0
# time elapsed on nsr              0
# dtype: int64

# %%
df_2015.head()
# Out:
#                                vessel name               flag  \
# 1  Yasnyi (with floating crane СПК- 42150)             Russia
# 2                               Yong Sheng              China
# 3                               Winter Bay  St. Kitts & Nevis
# 4                                 Garmonia             Russia
# 5                                Happy Sky        Netherlands
#
#            ship operator           ice class              ship type  \
# 1              FBI "MRS"  Arc 5 (crane Ice2)                 Rescue
# 2         Cosco Shipping               Arc 4  General cargo carrier
# 3           Dalriada Ltd               Ice 1                 Reefer
# 4     Yuzmorrybflot Ltd.               Arc 4                 Reefer
# 5  BigLift Shipping B.V.               Arc 4  General cargo carrier
#
#                                           cargo type approx cargo weight (tn)  \
# 1                                                NaN                        0
# ...

# %%
# expand checkpoint fields separating date and time

df_2015[['Kara Gate date','Kara Gate time']] = df_2015['Kara Gate date and time'].str.split(n=1,expand=True)
df_2015.drop('Kara Gate date and time',axis=1,inplace=True)

df_2015[['Cape Zhelaniya date','Cape Zhelaniya time']] = df_2015['Cape Zhelaniya date and time'].str.split(n=1,expand=True)
df_2015.drop('Cape Zhelaniya date and time',axis=1,inplace=True)

df_2015[['Cape Dezhnev date','Cape Deshnev time']] = df_2015['Cape Dezhnev date and time'].str.split(n=1,expand=True)
df_2015.drop('Cape Dezhnev date and time',axis=1,inplace=True)

# %%
df_2015.head()
# Out:
#                                vessel name               flag  \
# 1  Yasnyi (with floating crane СПК- 42150)             Russia
# 2                               Yong Sheng              China
# 3                               Winter Bay  St. Kitts & Nevis
# 4                                 Garmonia             Russia
# 5                                Happy Sky        Netherlands
#
#            ship operator           ice class              ship type  \
# 1              FBI "MRS"  Arc 5 (crane Ice2)                 Rescue
# 2         Cosco Shipping               Arc 4  General cargo carrier
# 3           Dalriada Ltd               Ice 1                 Reefer
# 4     Yuzmorrybflot Ltd.               Arc 4                 Reefer
# 5  BigLift Shipping B.V.               Arc 4  General cargo carrier
#
#                                           cargo type approx cargo weight (tn)  \
# 1                                                NaN                        0
# ...

# %%
df_2015.tail()
# Out:
#      vessel name    flag                       ship operator ice class  \
# 14        Yasnyi  Russia                           FBI "MRS"     Arc 5
# 15  Volk Arktiki  Russia  LLC Riboloveckaya Artel Vilychinsk     Ice 3
# 16      Palladiy  Russia                          Valkur Ltd     Arc 5
# 17      Kigoriak  Russia                          Femco Mng.      Ib 6
# 18    Tor Viking  Sweden             Viking Supply Ships A/S     Arc 7
#
#     ship type cargo type approx cargo weight (tn) max draught  \
# 14     Rescue        NaN                        0         4.9
# 15   Fishinng    Ballast                        0         4.0
# 16     Tanker    Ballast                        0         6.4
# 17  Iceb. Tug        NaN                        0         8.3
# 18  Iceb. Tug        NaN                        0         7.2
#
#              port of departure       port of arrival icebreaker assistance  \
# 14  Petropavlovsk- Kamchatskiy              Murmansk                    No
# ...

# %%
# 2016

df_2016 = data[2016]

df_2016.head()
# Out:
#    Unnamed: 0   0  1                   2          3  \
# 0           0 NaN  №         Vessel name       Flag
# 1           1 NaN  1  Kapitan Khlebnikov     Russia
# 2           2 NaN  2        Brage Viking     Russia
# 3           3 NaN  3          Yong Sheng  Hong Kong
# 4           4 NaN  4      Spasatel Karev     Russia
#
#                                                  4             5  \
# 0                                        Shipowner     Ice class
# 1             PJSC "Far Eastern\nShipping Company"  Icebreaker 7
# 2                              LLC "Viking Supply"         Arc 5
# 3                               Cosco Shipping Ltd         Arc 4
# 4  FBI “Marine Rescue\nService of\nRosmorrechflot”         Arc 5
#
#                         6                  7                       8  \
# 0                    Type              Cargo  Qty (mt) /\npassangers
# 1              Icebreaker         Passangers                     120
# ...

# %%
df_2016.tail()
# Out:
#     Unnamed: 0   0      1               2           3  \
# 16          16 NaN     17         Normann     Liberia
# 17          17 NaN     18  HHL Valparaiso     Liberia
# 18          18 NaN     19           Pomor     Liberia
# 19          19 NaN  Total             NaN       Cargo
# 20          20 NaN    NaN             NaN  Passangers
#
#                             4      5                       6  \
# 16  LLC ''Femko\nmanagement''  Arc 7           Supply vessel
# 17           Hansa Heavy Lift  Arc 4  General cargo\ncarrier
# 18  LLC ''Femko\nmanagement''  Arc 7           Supply vessel
# 19                        NaN    NaN                     NaN
# 20                        NaN    NaN                     NaN
#
#                                              7        8        9   10  \
# 16                                         NaN        0    2 600  7,6
# 17  Port crandes; sand in\nbig-bags; invertors    4 097   19 413  8,8
# ...

# %%
# standardize column names

df_2016.columns = ['index','index2','index3','vessel name','flag','ship operator','ice class',
                   'ship type','cargo type','approx cargo weight (tn)','dead weight tonnage',
                   'max draught','port of departure','port of arrival','icebreaker assistance',
                   'Kara Gate date and time','Yugorskiy Strait date and time','Cape Zhelaniya date and time',
                   'Cape Dezhnev date and time','time elapsed on nsr']

df_2016.head()
# Out:
#    index  index2 index3         vessel name       flag  \
# 0      0     NaN      №         Vessel name       Flag
# 1      1     NaN      1  Kapitan Khlebnikov     Russia
# 2      2     NaN      2        Brage Viking     Russia
# 3      3     NaN      3          Yong Sheng  Hong Kong
# 4      4     NaN      4      Spasatel Karev     Russia
#
#                                      ship operator     ice class  \
# 0                                        Shipowner     Ice class
# 1             PJSC "Far Eastern\nShipping Company"  Icebreaker 7
# 2                              LLC "Viking Supply"         Arc 5
# 3                               Cosco Shipping Ltd         Arc 4
# 4  FBI “Marine Rescue\nService of\nRosmorrechflot”         Arc 5
#
#                 ship type         cargo type approx cargo weight (tn)  \
# 0                    Type              Cargo   Qty (mt) /\npassangers
# 1              Icebreaker         Passangers                      120
# ...

# %%
# drop unnecessary columns

df_2016.drop(['index','index2','index3'],axis=1,inplace=True)
df_2016.drop([0,19,20],axis=0,inplace=True)

df_2016.tail()
# Out:
#         vessel name                flag               ship operator ice class  \
# 14       Winter Bay  St. Kitts &\nNevis                Darliada Ltd     Ice 1
# 15  Inzhener Trubin              Russia  Northern Shipping\nCompany     Arc 5
# 16          Normann             Liberia   LLC ''Femko\nmanagement''     Arc 7
# 17   HHL Valparaiso             Liberia            Hansa Heavy Lift     Arc 4
# 18            Pomor             Liberia   LLC ''Femko\nmanagement''     Arc 7
#
#                  ship type                                  cargo type  \
# 14                  Refeer                                 Frozen fish
# 15  General cargo\ncarrier                                     Ballast
# 16           Supply vessel                                         NaN
# 17  General cargo\ncarrier  Port crandes; sand in\nbig-bags; invertors
# 18           Supply vessel                                         NaN
#
#    approx cargo weight (tn) dead weight tonnage max draught  \
# ...

# %%
df_2016 = basic_clean(df_2016)
# Out:
# [ ship operator 4 ]
# New line characters have been removed. Detected 1 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name                        0
# flag                               0
# ship operator                      0
# ice class                          0
# ship type                          0
# cargo type                         6
# approx cargo weight (tn)           0
# dead weight tonnage                0
# max draught                        1
# port of departure                  0
# port of arrival                    0
# icebreaker assistance              3
# Kara Gate date and time           15
# Yugorskiy Strait date and time    17
# Cape Zhelaniya date and time       4
# Cape Dezhnev date and time         0
# time elapsed on nsr                0
# dtype: int64

# %%
df_2016.head()
# Out:
#           vessel name       flag  \
# 1  Kapitan Khlebnikov     Russia
# 2        Brage Viking     Russia
# 3          Yong Sheng  Hong Kong
# 4      Spasatel Karev     Russia
# 5    Gretke Oldendorf   Portugal
#
#                                    ship operator     ice class  \
# 1            PJSC "Far Eastern Shipping Company"  Icebreaker 7
# 2                            LLC "Viking Supply"         Arc 5
# 3                             Cosco Shipping Ltd         Arc 4
# 4  FBI “Marine Rescue Service of Rosmorrechflot”         Arc 5
# 5               Oldendorff Carriers GmbH & Co KG         Ice 2
#
#                ship type         cargo type approx cargo weight (tn)  \
# 1             Icebreaker         Passangers                      120
# 2                    Tug                NaN                        0
# 3  General cargo carrier  Ore in bulk.steel                   13 514
# 4                 Rescue                NaN                        0
# ...

# %%
# expand columns 

df_2016[['Kara Gate date','Kara Gate time']] = df_2016['Kara Gate date and time'].str.split(n=1,expand=True)

df_2016[['Yugorskiy Strait date','Yugorskiy Strait time']] = df_2016['Yugorskiy Strait date and time'].str.split(n=1,expand=True)

df_2016[['Cape Zhelaniya date','Cape Zhelaniya time']] = df_2016['Cape Zhelaniya date and time'].str.split(n=1,expand=True)

df_2016[['Cape Dezhnev date','Cape Dezhnev time']] = df_2016['Cape Dezhnev date and time'].str.split(n=1,expand=True)

df_2016.drop(['Kara Gate date and time','Yugorskiy Strait date and time','Cape Zhelaniya date and time','Cape Dezhnev date and time'],axis=1,inplace=True)

# %%
df_2016.head()
# Out:
#           vessel name       flag  \
# 1  Kapitan Khlebnikov     Russia
# 2        Brage Viking     Russia
# 3          Yong Sheng  Hong Kong
# 4      Spasatel Karev     Russia
# 5    Gretke Oldendorf   Portugal
#
#                                    ship operator     ice class  \
# 1            PJSC "Far Eastern Shipping Company"  Icebreaker 7
# 2                            LLC "Viking Supply"         Arc 5
# 3                             Cosco Shipping Ltd         Arc 4
# 4  FBI “Marine Rescue Service of Rosmorrechflot”         Arc 5
# 5               Oldendorff Carriers GmbH & Co KG         Ice 2
#
#                ship type         cargo type approx cargo weight (tn)  \
# 1             Icebreaker         Passangers                      120
# 2                    Tug                NaN                        0
# 3  General cargo carrier  Ore in bulk.steel                   13 514
# 4                 Rescue                NaN                        0
# ...

# %%
# 2017

df_2017 = data[2017]

df_2017.head()
# Out:
#    Unnamed: 0  0            1      2      3                    4          5  \
# 0           0  N  Vessel name    DWT    GRT                 Flag  Shipowner
# 1           1  1    Tian Jian  38146  26770                China      COSCO
# 2           2  2        Da An  28000  22566            Hong Kong      COSCO
# 3           3  3    Foresight  12669   9611  Antigua and Barbuda        BBC
# 4           4  4      Fortune  12692   9611  Antigua and Barbuda        BBC
#
#                6        7      8          9            10                11  \
# 0    Vessel type      IMO    LOA  Ice class  Port of exit         Exit date
# 1     Heavy Lift  9722754    190      Ice 1   Lianyungang   31.08.2017 7:00
# 2     Heavy Lift  9607825  179,5      Ice 1       Tianjin   22.08.2017 2:00
# 3  General cargo  9388912  138,8      Arc 4       Taicang  08.08.2017 10:00
# 4  General cargo  9402067    139      Arc 4       Tiacang   11.09.2017 1:00
#
# ...

# %%
df_2017.tail()
# Out:
#     Unnamed: 0   0               1      2      3             4  \
# 23          23  23       Egvekinot   6026   4110        Russia
# 24          24  24        HHL Elbe  12709   9627       Liberia
# 25          25  25         Siziman   4800   4464  Sierra Leone
# 26          26  26  Rolldock Storm   9063  15382   Netherlands
# 27          27  27       Garmoniya   3642   4295        Russia
#
#                     5              6        7      8      9            10  \
# 23        Oil-Compact         Tanker  7912044  106,1  Arc 4      Murmansk
# 24                HHL  General cargo  9433262  138,5  Arc 4      Aberdeen
# 25     Garten Holding  General cargo  9113604  117,6  Arc 4      Murmansk
# 26  RollDock Shipping     Heavy load  9656503  151,5  Ice 3  Severodvinsk
# 27     Yuzhmorrybflot         Reefer  8516639    103  Arc 4        Ossora
#
#                   11            12        13            14        15  \
# ...

# %%
df_2017.columns = ['index','index2','vessel name','dead weight tonnage','grt',
                   'flag','ship operator','ship type','imo ship id','length overall',
                   'ice class','port of departure','departure date and time',
                   'nsr entrance point','nsr entry date','nsr exit point','nsr exit date',
                   'port of arrival','date of arrival','time elapsed on nsr']

df_2017.head()
# Out:
#    index index2  vessel name dead weight tonnage    grt                 flag  \
# 0      0      N  Vessel name                 DWT    GRT                 Flag
# 1      1      1    Tian Jian               38146  26770                China
# 2      2      2        Da An               28000  22566            Hong Kong
# 3      3      3    Foresight               12669   9611  Antigua and Barbuda
# 4      4      4      Fortune               12692   9611  Antigua and Barbuda
#
#   ship operator      ship type imo ship id length overall  ice class  \
# 0     Shipowner    Vessel type         IMO            LOA  Ice class
# 1         COSCO     Heavy Lift     9722754            190      Ice 1
# 2         COSCO     Heavy Lift     9607825          179,5      Ice 1
# 3           BBC  General cargo     9388912          138,8      Arc 4
# 4           BBC  General cargo     9402067            139      Arc 4
#
#   port of departure departure date and time nsr entrance point nsr entry date  \
# ...

# %%
# drop unnecessary columns

df_2017.drop(['index','index2'],axis=1,inplace=True)

df_2017.drop(0,axis=0,inplace=True)

df_2017.head()
# Out:
#   vessel name dead weight tonnage    grt                 flag ship operator  \
# 1   Tian Jian               38146  26770                China         COSCO
# 2       Da An               28000  22566            Hong Kong         COSCO
# 3   Foresight               12669   9611  Antigua and Barbuda           BBC
# 4     Fortune               12692   9611  Antigua and Barbuda           BBC
# 5     Finesse               12685   9611  Antigua and Barbuda           BBC
#
#        ship type imo ship id length overall ice class port of departure  \
# 1     Heavy Lift     9722754            190     Ice 1       Lianyungang
# 2     Heavy Lift     9607825          179,5     Ice 1           Tianjin
# 3  General cargo     9388912          138,8     Arc 4           Taicang
# 4  General cargo     9402067            139     Arc 4           Tiacang
# 5  General cargo     9388900            138     Arc 4           Taicang
#
# ...

# %%
df_2017 = basic_clean(df_2017)
# Out:
# New line characters have been removed. Detected 0 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name                0
# dead weight tonnage        0
# grt                        0
# flag                       0
# ship operator              0
# ship type                  0
# imo ship id                0
# length overall             0
# ice class                  0
# port of departure          0
# departure date and time    0
# nsr entrance point         0
# nsr entry date             0
# nsr exit point             0
# nsr exit date              0
# port of arrival            0
# date of arrival            0
# time elapsed on nsr        0
# dtype: int64

# %%
# expand columns
df_2017[['date of departure','time of departure']] = df_2017['departure date and time'].str.split(n=1,expand=True)
df_2017.drop('departure date and time',axis=1,inplace=True)

# %%
df_2017.tail()
# Out:
#        vessel name dead weight tonnage    grt          flag  \
# 23       Egvekinot                6026   4110        Russia
# 24        HHL Elbe               12709   9627       Liberia
# 25         Siziman                4800   4464  Sierra Leone
# 26  Rolldock Storm                9063  15382   Netherlands
# 27       Garmoniya                3642   4295        Russia
#
#         ship operator      ship type imo ship id length overall ice class  \
# 23        Oil-Compact         Tanker     7912044          106.1     Arc 4
# 24                HHL  General cargo     9433262          138.5     Arc 4
# 25     Garten Holding  General cargo     9113604          117.6     Arc 4
# 26  RollDock Shipping     Heavy load     9656503          151.5     Ice 3
# 27     Yuzhmorrybflot         Reefer     8516639            103     Arc 4
#
#    port of departure nsr entrance point nsr entry date nsr exit point  \
# 23          Murmansk          Kara Gate       15.08.17   Cape Dezhnev
# ...

# %%
# 2018

df_2018 = data[2018]
df_2018.head()
# Out:
#    Unnamed: 0    0            1         2      3      4               5  \
# 0           0  NaN       Vessel       NaN    NaN    NaN             NaN
# 1           1  NaN  Vessel name  Iceclass   Flag  Owner     Vessel type
# 2           2  1.0     Tian Hui     Arc 4  China  COSCO  General\ncargo
# 3           3  2.0     Tian You     Arc 4  China  COSCO  General\ncargo
# 4           4  3.0    Tian Jian     Ice 1  China  COSCO      Heavy Load
#
#        6          7       8         9              10        11  \
# 0    NaN  Departure     NaN       NaN             NSR       NaN
# 1    GRT    Country    Port      Date  Point of entry     Entry
# 2  26787    Germany   Emden  05.07.18     C.Zhelaniya  24.07.18
# 3  26787    S Korea   Busan  20.07.18       C.Dezhnev  28.07.18
# 4  26770    Denmark  Skagen  30.07.18     C.Zhelaniya  05.08.18
#
#               12        13       14         15        16
# 0            NaN       NaN  Arrival        NaN       NaN
# ...

# %%
df_2018.tail()
# Out:
#     Unnamed: 0     0             1      2       3             4  \
# 24          24  23.0      Tian Hui  Arc 4   China         COSCO
# 25          25  24.0     Egvekinot  Arc 4  Russia   Oil-Compact
# 26          26  25.0      Tian You  Arc 4   China         COSCO
# 27          27  26.0          Argo  Ice 2  Russia  Neva-Charter
# 28          28  27.0  Novorossiysk   ib 6  Russia    Rosmorport
#
#                  5      6       7              8         9           10  \
# 24  General\ncargo  26787   China        Jiangsu  20.09.18    C.Dezhnev
# 25          Tanker   4110  Russia    Arkhangelsk  05.09.18    Kara Gate
# 26  General\ncargo  26787  Norway     Hyefjorden  28.09.18  C.Zhelaniya
# 27             Tug    467  Russia  P.Kamchatskiy  24.09.18    C.Dezhnev
# 28      Icebreaker  13867  Russia       Murmansk  22.11.18    Kara Gate
#
#           11           12        13      14           15        16
# 24  30.09.18  C.Zhelaniya  06.10.18  Sweden   Oskarshamn  15.10.18
# ...

# %%
df_2018.columns = ['index','index2','vessel name','ice class','flag','ship operator','ship type',
                   'grt','country of departure','port of departure','date of departure',
                   'nsr entry point','nsr entry date','nsr exit point','nsr exit date',
                   'country of arrival','port of arrival','date of arrival']
df_2018.head()
# Out:
#    index  index2  vessel name ice class   flag ship operator       ship type  \
# 0      0     NaN       Vessel       NaN    NaN           NaN             NaN
# 1      1     NaN  Vessel name  Iceclass   Flag         Owner     Vessel type
# 2      2     1.0     Tian Hui     Arc 4  China         COSCO  General\ncargo
# 3      3     2.0     Tian You     Arc 4  China         COSCO  General\ncargo
# 4      4     3.0    Tian Jian     Ice 1  China         COSCO      Heavy Load
#
#      grt country of departure port of departure date of departure  \
# 0    NaN            Departure               NaN               NaN
# 1    GRT              Country              Port              Date
# 2  26787              Germany             Emden          05.07.18
# 3  26787              S Korea             Busan          20.07.18
# 4  26770              Denmark            Skagen          30.07.18
#
#   nsr entry point nsr entry date nsr exit point nsr exit date  \
# ...

# %%
df_2018.drop(['index','index2'],axis=1,inplace=True)
df_2018.drop([0,1],axis=0,inplace=True)
df_2018.reset_index(drop=True,inplace=True)
df_2018.head()
# Out:
#        vessel name ice class      flag      ship operator       ship type  \
# 0         Tian Hui     Arc 4     China              COSCO  General\ncargo
# 1         Tian You     Arc 4     China              COSCO  General\ncargo
# 2        Tian Jian     Ice 1     China              COSCO      Heavy Load
# 3  Atlantic Winter     Arc 4  Portugal    Atlantic Winter  General\ncargo
# 4           Kairos        No    Russia  Morskoy\nStandard          Tanker
#
#      grt country of departure port of departure date of departure  \
# 0  26787              Germany             Emden          05.07.18
# 1  26787              S Korea             Busan          20.07.18
# 2  26770              Denmark            Skagen          30.07.18
# 3  15549                China           Taicang          30.07.18
# 4  27526               Russia     P.Kamchatskiy          08.08.18
#
#   nsr entry point nsr entry date nsr exit point nsr exit date  \
# ...

# %%
df_2018 = basic_clean(df_2018)
df_2018.head()
# Out:
# New line characters have been removed. Detected 0 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name             0
# ice class               0
# flag                    0
# ship operator           0
# ship type               0
# grt                     0
# country of departure    0
# port of departure       0
# date of departure       0
# nsr entry point         0
# nsr entry date          0
# nsr exit point          0
# nsr exit date           0
# country of arrival      0
# port of arrival         0
# date of arrival         0
# dtype: int64
#        vessel name ice class      flag     ship operator      ship type  \
# 0         Tian Hui     Arc 4     China             COSCO  General cargo
# 1         Tian You     Arc 4     China             COSCO  General cargo
# 2        Tian Jian     Ice 1     China             COSCO     Heavy Load
# 3  Atlantic Winter     Arc 4  Portugal   Atlantic Winter  General cargo
# ...

# %%
# 2019

df_2019 = data[2019]
df_2019.head()
# Out:
#               Vessel name      IMO Ice class       Flag Owner / Operator  \
# 0                 Tian En  9774587     Arc 4      China            COSCO
# 1            Svyatoy Petr  9035838     Arc 4     Russia           Valkur
# 2  Professor Multanovskiy  8010362     Arc 5     Russia           FERHRI
# 3                  Da Tai  9608386     Ice 1  Hong Kong            COSCO
# 4               Simfoniya  8516627     Arc 4     Russia     Transrefflot
#
#      Vessel type    DWT    GRT    LOA Dep Country                   Dep Port  \
# 0  General cargo  37125  26787  190.0       China                   Changshu
# 1         Tanker  10960   6441  127.2      Russia  Petropavlovsk-Kamchatskiy
# 2       Research    620   1753   72.0      Russia                Vladivostok
# 3  General cargo  29881  22566  179.5       China                    Taicang
# 4         Reefer   3750   4298  103.0      Russia                     Ossora
#
#      Dep Date Arr Country     Arr Port    Arr Date
# ...

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Vessel name       36 non-null     object
#  1   IMO               36 non-null     int64
#  2   Ice class         36 non-null     object
#  3   Flag              36 non-null     object
#  4   Owner / Operator  36 non-null     object
#  5   Vessel type       36 non-null     object
#  6   DWT               36 non-null     int64
#  7   GRT               36 non-null     int64
#  8   LOA               36 non-null     float64
#  9   Dep Country       36 non-null     object
#  10  Dep Port          36 non-null     object
#  11  Dep Date          36 non-null     object
#  12  Arr Country       36 non-null     object
#  13  Arr Port          36 non-null     object
#  14  Arr Date          36 non-null     object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 4.3+ KB

# %%
df_2019.columns = ['vessel name','imo ship id','ice class','flag','ship operator','ship type','dead weight tonnage','grt','length overall','country of departure','port of departure','date of departure','country of arrival','port of arrival','date of arrival']

# %%
df_2019.head()
# Out:
#               vessel name  imo ship id ice class       flag ship operator  \
# 0                 Tian En      9774587     Arc 4      China         COSCO
# 1            Svyatoy Petr      9035838     Arc 4     Russia        Valkur
# 2  Professor Multanovskiy      8010362     Arc 5     Russia        FERHRI
# 3                  Da Tai      9608386     Ice 1  Hong Kong         COSCO
# 4               Simfoniya      8516627     Arc 4     Russia  Transrefflot
#
#        ship type  dead weight tonnage    grt  length overall  \
# 0  General cargo                37125  26787           190.0
# 1         Tanker                10960   6441           127.2
# 2       Research                  620   1753            72.0
# 3  General cargo                29881  22566           179.5
# 4         Reefer                 3750   4298           103.0
#
#   country of departure          port of departure date of departure  \
# 0                China                   Changshu        2019-07-19
# ...

# %%
df_2019 = basic_clean(df_2019)
# Out:
# New line characters have been removed. Detected 0 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name             0
# imo ship id             0
# ice class               0
# flag                    0
# ship operator           0
# ship type               0
# dead weight tonnage     0
# grt                     0
# length overall          0
# country of departure    0
# port of departure       0
# date of departure       0
# country of arrival      0
# port of arrival         0
# date of arrival         0
# dtype: int64

# %%
# 2020

df_2020 = data[2020]

df_2020.head()
# Out:
#        Vessel name      IMO Ice class     Flag           Owner / Operator  \
# 0          Barents  9278600     Arc 4   Russia               Eco Shipping
# 1      S,Kuznetsov  9210359     Arc 4   Russia  Northern Shipping Company
# 2  Nordic Svalbard  9437323     Arc 4  Liberia            Nordic Svalbard
# 3          Tian En  9774587     Arc 4    China                      COSCO
# 4           Samson  9114751     Arc 4   Russia    Morskoy Standard-Bunker
#
#      Vessel type    DWT    GRT    LOA Dep Country      Dep Port    Dep Date  \
# 0  General cargo   4303   3198   98.9      Russia  Severodvinsk  2020-07-17
# 1  General cargo   7625   6204  107.8      Russia     Belomorsk  2020-07-20
# 2  General cargo  16543  15549  133.0      Norway  Jossingfjord  2020-07-21
# 3  General cargo  37125  26787  190.0       China   Lianyungang  2020-07-26
# 4         Tanker   5870   3726   99.8      Russia   Arkhangelsk  2020-07-27
#
#   Arr Country                   Arr Port    Arr Date
# ...

# %%
df_2020.tail()
# Out:
#                   Vessel name      IMO     Ice class              Flag  \
# 59            Golden Strength  9413420         Ice 2  Marshall Islands
# 60                UHL Partner  9418999         Arc 4          Portugal
# 61               Golden Pearl  9470375         Ice 2  Marshall Islands
# 62  Boris Vilkitskiy (Tanker)  9000247         Arc 4            Russia
# 63               SCF Sakhalin  9307724  Icebreaker 6            Russia
#
#      Owner / Operator    Vessel type    DWT    GRT     LOA Dep Country  \
# 59            Suek AG           Bulk  75744  41655  225.00      Russia
# 60  United Heavy Lift  General cargo  16523  15549  166.14      Russia
# 61            Suek AG           Bulk  74300  41718  225.00      Russia
# 62  Khatanga Sea Port         Tanker   6760   5025  108.40      Russia
# 63                SCF         Supply   4298   6882  100.00      Russia
#
#         Dep Port    Dep Date Arr Country    Arr Port    Arr Date
# ...

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Vessel name       64 non-null     object
#  1   IMO               64 non-null     int64
#  2   Ice class         64 non-null     object
#  3   Flag              64 non-null     object
#  4   Owner / Operator  64 non-null     object
#  5   Vessel type       64 non-null     object
#  6   DWT               64 non-null     int64
#  7   GRT               64 non-null     int64
#  8   LOA               64 non-null     float64
#  9   Dep Country       64 non-null     object
#  10  Dep Port          64 non-null     object
#  11  Dep Date          64 non-null     object
#  12  Arr Country       64 non-null     object
#  13  Arr Port          64 non-null     object
#  14  Arr Date          64 non-null     object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 7.6+ KB

# %%
df_2020.columns = ['vessel name','imo ship id','ice class','flag','ship operator','ship type','dead weight tonnage','grt','length overall','country of departure','port of departure','date of departure','country of arrival','port of arrival','date of arrival']
df_2020.head()
# Out:
#        vessel name  imo ship id ice class     flag              ship operator  \
# 0          Barents      9278600     Arc 4   Russia               Eco Shipping
# 1      S,Kuznetsov      9210359     Arc 4   Russia  Northern Shipping Company
# 2  Nordic Svalbard      9437323     Arc 4  Liberia            Nordic Svalbard
# 3          Tian En      9774587     Arc 4    China                      COSCO
# 4           Samson      9114751     Arc 4   Russia    Morskoy Standard-Bunker
#
#        ship type  dead weight tonnage    grt  length overall  \
# 0  General cargo                 4303   3198            98.9
# 1  General cargo                 7625   6204           107.8
# 2  General cargo                16543  15549           133.0
# 3  General cargo                37125  26787           190.0
# 4         Tanker                 5870   3726            99.8
#
#   country of departure port of departure date of departure country of arrival  \
# ...

# %%
df_2020 = basic_clean(df_2020)
# Out:
# New line characters have been removed. Detected 0 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name             0
# imo ship id             0
# ice class               0
# flag                    0
# ship operator           0
# ship type               0
# dead weight tonnage     0
# grt                     0
# length overall          0
# country of departure    0
# port of departure       0
# date of departure       0
# country of arrival      0
# port of arrival         0
# date of arrival         0
# dtype: int64

# %%
# 2021

df_2021 = data[2021]

df_2021.head()
# Out:
#       Vessel name      IMO Ice class              Flag  \
# 0         Tian En  9774587     Arc 4             China
# 1  Admiral Shmidt  9838838     Arc 5           Bahamas
# 2          Pugnax  9763849     Arc 7           Liberia
# 3  Golden Furious  9860128     Ice 2  Marshall Islands
# 4   Svyatoy Pavel  9035826     Arc 4            Russia
#
#             Owner / Operator    Vessel type     DWT    GRT    LOA  \
# 0                      COSCO  General cargo   37125  26787  190.0
# 1               GTLK Asia M3           Bulk  104553  66291  250.0
# 2  Fortune MC Titan Shipping     Heavy Load   28816  34146  206.3
# 3         Furious Shipowning           Bulk   81600  44094  229.0
# 4                     Valkur         Tanker   10926   6441  127.2
#
#    Dep Country      Dep Port    Dep Date Arr Country     Arr Port    Arr Date
# 0      Finland      Helsinki  2021-06-23       China      Qingdao  2021-08-17
# 1       Russia      Nakhodka  2021-07-07      Canada      Nunavut  2021-08-11
# ...

# %%
df_2021.tail()
# Out:
#      Vessel name      IMO Ice class              Flag  \
# 82    UHL Fusion  9785380     Arc 4          Portugal
# 83  Golden Pearl  9470375     Ice 2  Marshall Islands
# 84       Kumpula  9590802     Arc 4           Finland
# 85     Sevmorput  8729810     Arc 5            Russia
# 86        Pugnax  9763849     Arc 7           Liberia
#
#              Owner / Operator    Vessel type    DWT    GRT    LOA Dep Country  \
# 82             Elmar Shipping  General cargo  17147  16732  150.0     Denmark
# 83                    Suek AG           Bulk  74300  41718  225.0      Russia
# 84                    Suek AG           Bulk  56348  33958  197.0       China
# 85                   Atomflot      Container  33240  38226  260.0      Russia
# 86  Fortune MC Titan Shipping     Heavy Load  28816  34146  206.3       China
#
#           Dep Port    Dep Date Arr Country       Arr Port    Arr Date
# 82         Esbjerg  2021-10-25      Russia  Bolshoy Kamen  2021-11-29
# ...

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Vessel name       87 non-null     object
#  1   IMO               87 non-null     int64
#  2   Ice class         87 non-null     object
#  3   Flag              87 non-null     object
#  4   Owner / Operator  87 non-null     object
#  5   Vessel type       87 non-null     object
#  6   DWT               87 non-null     int64
#  7   GRT               87 non-null     int64
#  8   LOA               87 non-null     float64
#  9   Dep Country       87 non-null     object
#  10  Dep Port          87 non-null     object
#  11  Dep Date          87 non-null     object
#  12  Arr Country       87 non-null     object
#  13  Arr Port          87 non-null     object
#  14  Arr Date          87 non-null     object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 10.3+ KB

# %%
df_2021.columns = ['vessel name','imo ship id','ice class','flag','ship operator','ship type','dead weight tonnage','grt','length overall','country of departure','port of departure','date of departure','country of arrival','port of arrival','date of arrival']
df_2021.head()
# Out:
#       vessel name  imo ship id ice class              flag  \
# 0         Tian En      9774587     Arc 4             China
# 1  Admiral Shmidt      9838838     Arc 5           Bahamas
# 2          Pugnax      9763849     Arc 7           Liberia
# 3  Golden Furious      9860128     Ice 2  Marshall Islands
# 4   Svyatoy Pavel      9035826     Arc 4            Russia
#
#                ship operator      ship type  dead weight tonnage    grt  \
# 0                      COSCO  General cargo                37125  26787
# 1               GTLK Asia M3           Bulk               104553  66291
# 2  Fortune MC Titan Shipping     Heavy Load                28816  34146
# 3         Furious Shipowning           Bulk                81600  44094
# 4                     Valkur         Tanker                10926   6441
#
#    length overall country of departure port of departure date of departure  \
# 0           190.0              Finland          Helsinki        2021-06-23
# ...

# %%
df_2021 = basic_clean(df_2021)
# Out:
# New line characters have been removed. Detected 0 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name             0
# imo ship id             0
# ice class               0
# flag                    0
# ship operator           0
# ship type               0
# dead weight tonnage     0
# grt                     0
# length overall          0
# country of departure    0
# port of departure       0
# date of departure       0
# country of arrival      0
# port of arrival         0
# date of arrival         0
# dtype: int64

# %%
# 2022

df_2022 = data[2022]

df_2022.head()
# Out:
#     Vessel name      IMO Ice class     Flag  \
# 0         Audax  9763837     Arc 7  Curacao
# 1     Sevmorput  8729810     Arc 5   Russia
# 2       Ruslana  9352339     Arc 4   Russia
# 3  Svyatoy Petr  9035838     Arc 4   Russia
# 4     Sevmorput  8729810     Arc 5   Russia
#
#                     Owner / Operator    Vessel type    DWT    GRT  LOA  \
# 0  Fortune MC Hercules Shipping Ltd,  General cargo  28899  34387  206
# 1                           Atomflot      Container  33240  38226  260
# 2                          Transflot  General cargo   7750   5057  120
# 3                             Valkur         Tanker  10960   6441  127
# 4                           Atomflot      Container  33240  38226  260
#
#    Dep Country      Dep Port    Dep Date Arr Country  \
# 0        China       Tianjin  2021-12-29      Russia
# 1       Russia   Vladivostok  2022-01-17      Russia
# 2  South Korea         Masan  2022-06-25      Russia
# ...

# %%
df_2022.tail()
# Out:
#       Vessel name      IMO Ice class    Flag         Owner / Operator  \
# 38         PANDAR  9000235     Ice 2  Russia  Morskoy Standart Co Ltd
# 39       ELLADORA  8822375     Ice 1  Russia         DEFA Fishing LLC
# 40  VASILY DINKOV  9372547     Arc 6  Russia               SOVCOMFLOT
# 41    Monchegorsk  9404015     Arc 7  Russia           Norilsk Nickel
# 42      Sevmorput  8729810     Arc 5  Russia                 Atomflot
#
#    Vessel type    DWT    GRT  LOA Dep Country                   Dep Port  \
# 38      Tanker   6810   5025  116      Russia  Petropavlovsk-Kamchatskiy
# 39     Fishing   1919   1523   60      Norway                   Kirkenes
# 40      Tanker  72722  49597  257      Russia                   Murmansk
# 41   Container  18486  16994  169      Russia                   Nakhodka
# 42   Container  33240  38226  260      Russia                   Nakhodka
#
#       Dep Date Arr Country        Arr Port    Arr Date
# ...

# %%
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Vessel name       43 non-null     object
#  1   IMO               43 non-null     int64
#  2   Ice class         43 non-null     object
#  3   Flag              43 non-null     object
#  4   Owner / Operator  43 non-null     object
#  5   Vessel type       43 non-null     object
#  6   DWT               43 non-null     int64
#  7   GRT               43 non-null     int64
#  8   LOA               43 non-null     int64
#  9   Dep Country       43 non-null     object
#  10  Dep Port          43 non-null     object
#  11  Dep Date          43 non-null     object
#  12  Arr Country       43 non-null     object
#  13  Arr Port          43 non-null     object
#  14  Arr Date          43 non-null     object
# dtypes: int64(4), object(11)
# memory usage: 5.2+ KB

# %%
df_2022.columns = ['vessel name','imo ship id','ice class','flag','ship operator','ship type','dead weight tonnage','grt','length overall','country of departure','port of departure','date of departure','country of arrival','port of arrival','date of arrival']
df_2022.head()
# Out:
#     vessel name  imo ship id ice class     flag  \
# 0         Audax      9763837     Arc 7  Curacao
# 1     Sevmorput      8729810     Arc 5   Russia
# 2       Ruslana      9352339     Arc 4   Russia
# 3  Svyatoy Petr      9035838     Arc 4   Russia
# 4     Sevmorput      8729810     Arc 5   Russia
#
#                        ship operator      ship type  dead weight tonnage  \
# 0  Fortune MC Hercules Shipping Ltd,  General cargo                28899
# 1                           Atomflot      Container                33240
# 2                          Transflot  General cargo                 7750
# 3                             Valkur         Tanker                10960
# 4                           Atomflot      Container                33240
#
#      grt  length overall country of departure port of departure  \
# 0  34387             206                China           Tianjin
# 1  38226             260               Russia       Vladivostok
# ...

# %%
df_2022 = basic_clean(df_2022)
# Out:
# New line characters have been removed. Detected 0 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name             0
# imo ship id             0
# ice class               0
# flag                    0
# ship operator           0
# ship type               0
# dead weight tonnage     0
# grt                     0
# length overall          0
# country of departure    0
# port of departure       0
# date of departure       0
# country of arrival      0
# port of arrival         0
# date of arrival         0
# dtype: int64

# %%
# 2023

df_2023 = data[2023]

df_2023.head()
# Out:
#    Vessel name      IMO Ice class     Flag           Owner / Operator  \
# 0       Pugnax  9763849     Arc 7  Liberia  Fortune MC Titan Shipping
# 1    Sevmorput  8729810     Arc 5   Russia                   Atomflot
# 2    Chukotka+  7927960     Arc 4   Russia   Chukotka Trading Company
# 3  SCF Baltica  9305568     Arc 5  Liberia       Ashbourne Navigation
# 4       Pugnax  9763849     Arc 7  Liberia  Fortune MC Titan Shipping
#
#   Vessel type     DWT    GRT  LOA  Dep Country        Dep Port    Dep Date  \
# 0  Heavy Load   28816  34146  206  South Korea           Busan  2023-06-03
# 1   Container   33240  38226  260       Russia  St, Petersburg  2023-06-24
# 2      Tanker   11548   8806  141       Russia       Egvekinot  2023-07-04
# 3      Tanker  117153  65293  250       Russia      Vostochnyy  2023-07-07
# 4  Heavy Load   28816  34146  206       Russia        Murmansk  2023-07-07
#
#   Arr Country     Arr Port    Arr Date  Cargo Approx tn     Cargo type
# ...

# %%
df_2023.tail()
# Out:
#           Vessel name      IMO     Ice class       Flag    Owner / Operator  \
# 74              Gingo  9182710  No Ice Class    Liberia      Light Maritime
# 75              Almaz  9150224         Ice 1     Russia                MAGE
# 76          NS Arctic  9413547         Ice 3    Liberia  Ns Arctic Shipping
# 77  Newnew Polar Bear  9313204         Arc 5  Hong Kong  HAINANXIN XIN YANG
# 78          Sevmorput  8729810         Arc 5     Russia            Atomflot
#
#    Vessel type     DWT    GRT  LOA Dep Country                   Dep Port  \
# 74        Bulk  169159  86192  289       China                     Dalian
# 75         Tug      57    182   29      Russia                   Murmansk
# 76      Tanker  111107  62433  250      Russia                   Primorsk
# 77   Container   15952  16324  169      Russia                Arkhangelsk
# 78   Container   33240  38226  260      Russia  Petropavlovsk-Kamchatskiy
#
# ...

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Vessel name       79 non-null     object
#  1   IMO               79 non-null     int64
#  2   Ice class         79 non-null     object
#  3   Flag              79 non-null     object
#  4   Owner / Operator  79 non-null     object
#  5   Vessel type       79 non-null     object
#  6   DWT               79 non-null     int64
#  7   GRT               79 non-null     int64
#  8   LOA               79 non-null     int64
#  9   Dep Country       79 non-null     object
#  10  Dep Port          79 non-null     object
#  11  Dep Date          79 non-null     object
#  12  Arr Country       79 non-null     object
#  13  Arr Port          79 non-null     object
#  14  Arr Date          79 non-null     object
#  15  Cargo Approx tn   79 non-null     float64
# ...

# %%
df_2023.columns = ['vessel name','imo ship id','ice class','flag','ship operator','ship type','dead weight tonnage','grt','length overall','country of departure','port of departure','date of departure','country of arrival','port of arrival','date of arrival','approx cargo weight (tn)','cargo type']
df_2023.head()
# Out:
#    vessel name  imo ship id ice class     flag              ship operator  \
# 0       Pugnax      9763849     Arc 7  Liberia  Fortune MC Titan Shipping
# 1    Sevmorput      8729810     Arc 5   Russia                   Atomflot
# 2    Chukotka+      7927960     Arc 4   Russia   Chukotka Trading Company
# 3  SCF Baltica      9305568     Arc 5  Liberia       Ashbourne Navigation
# 4       Pugnax      9763849     Arc 7  Liberia  Fortune MC Titan Shipping
#
#     ship type  dead weight tonnage    grt  length overall  \
# 0  Heavy Load                28816  34146             206
# 1   Container                33240  38226             260
# 2      Tanker                11548   8806             141
# 3      Tanker               117153  65293             250
# 4  Heavy Load                28816  34146             206
#
#   country of departure port of departure date of departure country of arrival  \
# 0          South Korea             Busan        2023-06-03             Russia
# ...

# %%
df_2023 = basic_clean(df_2023)
# Out:
# New line characters have been removed. Detected 0 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name                 0
# imo ship id                 0
# ice class                   0
# flag                        0
# ship operator               0
# ship type                   0
# dead weight tonnage         0
# grt                         0
# length overall              0
# country of departure        0
# port of departure           0
# date of departure           0
# country of arrival          0
# port of arrival             0
# date of arrival             0
# approx cargo weight (tn)    0
# cargo type                  0
# dtype: int64

# %%
# 2024

df_2024 = data[2024]

df_2024.head()
# Out:
#    N          Ship_name      IMO  LOA     DWT Ice Class       Departure Date  \
# 0  1              Audax  9763837  206   28899     Arc 7  2024-01-06 00:00:00
# 1  1             Pugnax  9763849  206   28816     Arc 7  2024-01-06 00:00:00
# 2  1  Shturman_Skuratov  9759915  249   41041     Arc 7  2024-06-16 00:00:00
# 3  1   Korolev_Prospect  9826902  250  113232     Ice 3  2024-07-04 00:00:00
# 4  1         Xue_Long_2  9829241  122    4530     Arc 7  2024-07-05 00:00:00
#
#   Departure Port         Arrival Date Arrival     port Arrival Country  \
# 0        Penglai  2024-02-27 00:00:00         Murmansk          Russia
# 1        Penglai  2024-02-27 00:00:00         Murmansk          Russia
# 2       Murmansk  2024-07-10 00:00:00       Vostochnyy          Russia
# 3         Hainan  2024-08-12 00:00:00         Murmansk          Russia
# 4        Qingdao  2024-08-28 00:00:00         Murmansk          Russia
#
#       Cargo type  Cargo Approx NSR Entered NSR   Left         Days at NSR
# ...

# %%
df_2024.columns = ['del','vessel name','imo ship id','length overall','dead weight tonnage',
                   'ice class','date of departure','port of departure','date of arrival',
                   'port of arrival','country of arrival','cargo type','approx cargo weight (tn)',
                   'nsr entry date','nsr exit date','del1'
                  ]

df_2024.drop(['del','del1'],axis=1,inplace=True)

# %%
df_2024.head()
# Out:
#          vessel name  imo ship id  length overall  dead weight tonnage  \
# 0              Audax      9763837             206                28899
# 1             Pugnax      9763849             206                28816
# 2  Shturman_Skuratov      9759915             249                41041
# 3   Korolev_Prospect      9826902             250               113232
# 4         Xue_Long_2      9829241             122                 4530
#
#   ice class    date of departure port of departure      date of arrival  \
# 0     Arc 7  2024-01-06 00:00:00           Penglai  2024-02-27 00:00:00
# 1     Arc 7  2024-01-06 00:00:00           Penglai  2024-02-27 00:00:00
# 2     Arc 7  2024-06-16 00:00:00          Murmansk  2024-07-10 00:00:00
# 3     Ice 3  2024-07-04 00:00:00            Hainan  2024-08-12 00:00:00
# 4     Arc 7  2024-07-05 00:00:00           Qingdao  2024-08-28 00:00:00
#
#   port of arrival country of arrival     cargo type  approx cargo weight (tn)  \
# ...

# %%
df_2024.tail()
# Out:
#         vessel name  imo ship id  length overall  dead weight tonnage  \
# 92  Mikhail_Ulyanov      9333670             236                70000
# 93      Astrum_Apus      9467146             166                19306
# 94           Breeze      9305568             250               117153
# 95      Viktor_Tsoi      9609744             225                74559
# 96       Polar_King      8711320             133                 7346
#
#    ice class    date of departure port of departure      date of arrival  \
# 92     Arc 6  2024-10-12 00:00:00          Nakhodka  2024-10-27 00:00:00
# 93     Arc 4  2024-10-14 00:00:00          Nakhodka  2024-11-11 00:00:00
# 94     Arc 5  2024-10-16 00:00:00          Murmansk  2024-11-12 00:00:00
# 95     Ice 3  2024-10-18 00:00:00          Murmansk  2024-11-25 00:00:00
# 96     Arc 5  2024-10-21 00:00:00       Arkhangelsk  2024-11-17 00:00:00
#
#    port of arrival country of arrival     cargo type  \
# ...

# %%
df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   vessel name               97 non-null     object
#  1   imo ship id               97 non-null     int64
#  2   length overall            97 non-null     int64
#  3   dead weight tonnage       97 non-null     int64
#  4   ice class                 97 non-null     object
#  5   date of departure         97 non-null     object
#  6   port of departure         97 non-null     object
#  7   date of arrival           97 non-null     object
#  8   port of arrival           97 non-null     object
#  9   country of arrival        97 non-null     object
#  10  cargo type                97 non-null     object
#  11  approx cargo weight (tn)  97 non-null     int64
#  12  nsr entry date            97 non-null     object
#  13  nsr exit date             97 non-null     object
# ...

# %%
df_2024 = basic_clean(df_2024)
# Out:
# New line characters have been removed. Detected 0 cell(s) with non-ASCII characters.
# Null Count:
#  vessel name                 0
# imo ship id                 0
# length overall              0
# dead weight tonnage         0
# ice class                   0
# date of departure           0
# port of departure           0
# date of arrival             0
# port of arrival             0
# country of arrival          0
# cargo type                  0
# approx cargo weight (tn)    0
# nsr entry date              0
# nsr exit date               0
# dtype: int64

# %%
dfs = [df_2011,df_2012,temp_df_2013,df_2014,df_2015,df_2016,df_2017,df_2018,df_2019,df_2020,df_2021,df_2022,df_2023,df_2024]

# %%
df = pd.concat(dfs,ignore_index=True)

# %%
df.head()
# Out:
#          vessel name      ship type              flag      cargo type  \
# 0       Perseverance  Tanker vessel         Singapore  Gas condensate
# 1       STI Heritage  Tanker vessel  Marshall Islands  Gas condensate
# 2            Marilee  Tanker vessel            Norway  Gas condensate
# 3  Vladimir Tikhonov  Tanker vessel           Liberia  Gas condensate
# 4     Stena Poseidon  Tanker vessel           Finland  Gas condensate
#
#      port of departure        port of arrival ice class ship operator  \
# 0       Vitino. Russia          Ningbo. China       NaN           NaN
# 1       Vitino. Russia  Map Ta Phut. Thailand       NaN           NaN
# 2       Vitino. Russia         Huizhou. China       NaN           NaN
# 3  Honningsvåg. Norway  Map Ta Phut. Thailand       NaN           NaN
# 4       Vitino. Russia   Incheon. South Korea       NaN           NaN
#
#   time elapsed on nsr  avg speed  ... Yugorskiy Strait time Cape Dezhnev time  \
# ...

# %%
df.tail()
# Out:
#          vessel name ship type flag     cargo type port of departure  \
# 701  Mikhail_Ulyanov       NaN  NaN        Ballast          Nakhodka
# 702      Astrum_Apus       NaN  NaN  General cargo          Nakhodka
# 703           Breeze       NaN  NaN      Crude Oil          Murmansk
# 704      Viktor_Tsoi       NaN  NaN           Coal          Murmansk
# 705       Polar_King       NaN  NaN  General cargo       Arkhangelsk
#
#     port of arrival ice class ship operator time elapsed on nsr  avg speed  \
# 701   Prirazlomnaya     Arc 6           NaN                 NaN        NaN
# 702        Ust-Luga     Arc 4           NaN                 NaN        NaN
# 703          Ningbo     Arc 5           NaN                 NaN        NaN
# 704          Rizhao     Ice 3           NaN                 NaN        NaN
# 705   P.Kamchatskiy     Arc 5           NaN                 NaN        NaN
#
#      ... Yugorskiy Strait time Cape Dezhnev time imo ship id length overall  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   vessel name               705 non-null    object
#  1   ship type                 440 non-null    object
#  2   flag                      606 non-null    object
#  3   cargo type                409 non-null    object
#  4   port of departure         651 non-null    object
#  5   port of arrival           652 non-null    object
#  6   ice class                 611 non-null    object
#  7   ship operator             513 non-null    object
#  8   time elapsed on nsr       225 non-null    object
#  9   avg speed                 41 non-null     float64
#  10  date of departure         561 non-null    object
#  11  time of departure         110 non-null    object
#  12  nsr entry date            318 non-null    object
# ...

# %%
df['date of departure'].value_counts()
# Out:
# date of departure
# 2023-09-22             4
# 2024-09-06 00:00:00    4
# 2021-09-11             4
# 2022-09-08             4
# 2023-07-12             3
# 2024-07-17 00:00:00    3
# 2024-08-25 00:00:00    3
# 2023-08-08             3
# 2022-09-02             3
# 2024-09-21 00:00:00    3
# 2024-09-01 00:00:00    3
# 2012-07-10 00:00:00    3
# 2023-07-07             3
# 2021-08-06             3
# 2020-09-24             3
# 2021-07-21             3
# 2020-09-11             3
# 2024-09-09 00:00:00    3
# 2024-09-11 00:00:00    3
# 2020-09-12             3
# 2021-09-18             3
# 2021-10-10             3
# 03.10.2017             3
# 2012-10-17 00:00:00    2
# 13.08.13               2
# 2023-10-01             2
# 2024-10-12 00:00:00    2
# 2024-08-22 00:00:00    2
# 2023-09-05             2
# 2012-11-12 00:00:00    2
# 25.06.13               2
# 2024-08-28 00:00:00    2
# 2024-08-30 00:00:00    2
# 2024-08-16 00:00:00    2
# 2024-08-21 00:00:00    2
# 2012-09-30 00:00:00    2
# ...

# %%
df = df.apply(lambda x: x.str.casefold() if x.dtype == 'object' else x)

# %%
df['cargo type'].value_counts()
# Out:
# cargo type
# ballast                                               131
# general cargo                                          34
# crude oil                                              32
# containers                                             28
#  diesel fuel                                           17
# oil products tanker                                    12
#  general cargo                                         12
# gas condensate                                          9
# fish                                                    8
# crude oil tanker                                        8
# diesel fuel                                             8
# frozen fish                                             7
# coal                                                    7
# iron ore concentrate                                    6
# diesel oil                                              5
# oil/chemical tanker                                     5
# ...
